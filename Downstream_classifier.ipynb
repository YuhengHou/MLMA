# %% [markdown]
# # Compare embedding method

# %%
import torch
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'


# === Load embeddings ===
def load_embedding(path):
    data = torch.load(path)
    X = data['X']
    if X.ndim == 3 and X.shape[1] == 1:
        X = X.squeeze(1)
    X = X.numpy()
    y = data['y'].numpy()
    return X, y

X_delta, y_delta = load_embedding("data/esm2_delta_embeddings.pt")
X_mut, y_mut = load_embedding("data/esm2_embeddings.pt")

# === Classifiers ===
classifiers = {
    "SVM": SGDClassifier(loss="hinge", max_iter=1000, tol=1e-3),
    "MLP": MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=300, random_state=42),
    "XGBoost": XGBClassifier(
        tree_method="hist",    
        device="cuda",          
        n_estimators=100,
        random_state=42
    ),
    "LightGBM": LGBMClassifier(
        device="gpu",                 # Enable GPU
        boosting_type="gbdt",
        random_state=42,
        verbosity=-1
    )
}

# === Cross Validation ===
def evaluate_model(X, y, name=""):
    print(f"\n🔍 Evaluating on {name} embeddings")
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    
    results = {}
    for clf_name, clf in classifiers.items():
        accs, f1s = [], []
        for train_idx, test_idx in skf.split(X, y):
            X_train, X_test = X[train_idx], X[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]
            
            scaler = StandardScaler()
            X_train = scaler.fit_transform(X_train)
            X_test = scaler.transform(X_test)

            clf.fit(X_train, y_train)
            y_pred = clf.predict(X_test)
            accs.append(accuracy_score(y_test, y_pred))
            f1s.append(f1_score(y_test, y_pred, average="macro"))
        
        results[clf_name] = {
            "Accuracy": np.mean(accs),
            "MacroF1": np.mean(f1s)
        }
        print(f"  {clf_name}: Accuracy = {results[clf_name]['Accuracy']:.4f}, MacroF1 = {results[clf_name]['MacroF1']:.4f}")
    
    df = pd.DataFrame(results).T
    display(df)
    return df

# Run for both embeddings
delta_result = evaluate_model(X_delta, y_delta, name="ESM2-delta")
mut_result = evaluate_model(X_mut, y_mut, name="ESM2-mutated-only")
# Out:
# 🔍 Evaluating on ESM2-delta embeddings
#   SVM: Accuracy = 0.6576, MacroF1 = 0.2985
#   MLP: Accuracy = 0.8133, MacroF1 = 0.7116
#   XGBoost: Accuracy = 0.8533, MacroF1 = 0.7571
# /home/sunyvxuan/anaconda3/envs/MLMA/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/sunyvxuan/anaconda3/envs/MLMA/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/sunyvxuan/anaconda3/envs/MLMA/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/sunyvxuan/anaconda3/envs/MLMA/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
#   LightGBM: Accuracy = 0.7789, MacroF1 = 0.5923
# /home/sunyvxuan/anaconda3/envs/MLMA/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
#           Accuracy   MacroF1
# SVM       0.657614  0.298515
# MLP       0.813346  0.711579
# XGBoost   0.853260  0.757104
# LightGBM  0.778870  0.592319
# 🔍 Evaluating on ESM2-mutated-only embeddings
#   SVM: Accuracy = 0.6388, MacroF1 = 0.3469
#   MLP: Accuracy = 0.7203, MacroF1 = 0.5623
#   XGBoost: Accuracy = 0.7353, MacroF1 = 0.5458
# /home/sunyvxuan/anaconda3/envs/MLMA/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/sunyvxuan/anaconda3/envs/MLMA/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/sunyvxuan/anaconda3/envs/MLMA/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/sunyvxuan/anaconda3/envs/MLMA/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
#   LightGBM: Accuracy = 0.7185, MacroF1 = 0.4546
# /home/sunyvxuan/anaconda3/envs/MLMA/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
#           Accuracy   MacroF1
# SVM       0.638847  0.346896
# MLP       0.720294  0.562298
# XGBoost   0.735271  0.545824
# LightGBM  0.718542  0.454568

# %% [markdown]
# # DNN based model

# %% [markdown]
# ## Only Protein

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import os

# === Config ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 64
EPOCHS = 300
LR = 1e-4
NUM_CLASSES = 4

# === Load Data ===
data = torch.load("data/esm2_delta_embeddings.pt")
X = data['X']
if X.ndim == 3 and X.shape[1] == 1:
    X = X.squeeze(1)
y = data['y']

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# === Reshape to [B, T, D]
T = 4
D = X.shape[1] // T
X_train = X_train.reshape(-1, T, D)
X_val = X_val.reshape(-1, T, D)

# === DataLoader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# === Class weights
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_train.numpy()), y=y_train.numpy())
class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)

# === Transformer Classifier
class TransformerClassifier(nn.Module):
    def __init__(self, dim, heads=4, ff_dim=256, num_classes=4, dropout=0.1):
        super().__init__()
        encoder_layer = nn.TransformerEncoderLayer(d_model=dim, nhead=heads, dim_feedforward=ff_dim, dropout=dropout, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=2)
        self.classifier = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = x.mean(dim=1)  # Global average pooling
        return self.classifier(x)

model = TransformerClassifier(dim=D, num_classes=NUM_CLASSES).to(device)
optimizer = optim.AdamW(model.parameters(), lr=LR)
loss_fn = nn.CrossEntropyLoss(weight=class_weights)

# === Train loop
train_losses, val_accuracies = [], []

for epoch in range(1, EPOCHS+1):
    model.train()
    total_loss = 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        out = model(xb)
        loss = loss_fn(out, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    train_losses.append(total_loss / len(train_loader))

    # === Validation
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for xb, yb in val_loader:
            xb = xb.to(device)
            preds = model(xb).argmax(dim=1).cpu()
            all_preds.extend(preds)
            all_labels.extend(yb)
    acc = accuracy_score(all_labels, all_preds)
    val_accuracies.append(acc)
    print(f"Epoch {epoch:2d} | Loss: {train_losses[-1]:.4f} | Val Acc: {acc:.4f}")

# === Plot loss & accuracy
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Loss")
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.subplot(1, 2, 2)
plt.plot(val_accuracies, label="Val Acc", color="orange")
plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.tight_layout()
plt.show()

# === Final Evaluation
print("\n📊 Final Classification Report:")
print(classification_report(all_labels, all_preds, target_names=[f"Stage {i}" for i in range(NUM_CLASSES)]))
# Out:
# Epoch  1 | Loss: 1.3958 | Val Acc: 0.3611
# Epoch  2 | Loss: 1.3657 | Val Acc: 0.1268
# Epoch  3 | Loss: 1.3180 | Val Acc: 0.3265
# Epoch  4 | Loss: 1.2464 | Val Acc: 0.5821
# Epoch  5 | Loss: 1.1663 | Val Acc: 0.2367
# Epoch  6 | Loss: 1.0980 | Val Acc: 0.6095
# Epoch  7 | Loss: 1.0187 | Val Acc: 0.3824
# Epoch  8 | Loss: 0.9547 | Val Acc: 0.5189
# Epoch  9 | Loss: 0.8989 | Val Acc: 0.5200
# Epoch 10 | Loss: 0.8611 | Val Acc: 0.4564
# Epoch 11 | Loss: 0.8168 | Val Acc: 0.5409
# Epoch 12 | Loss: 0.7818 | Val Acc: 0.6264
# Epoch 13 | Loss: 0.7451 | Val Acc: 0.4327
# Epoch 14 | Loss: 0.7188 | Val Acc: 0.5050
# Epoch 15 | Loss: 0.6815 | Val Acc: 0.4748
# Epoch 16 | Loss: 0.6625 | Val Acc: 0.5189
# Epoch 17 | Loss: 0.6328 | Val Acc: 0.6364
# Epoch 18 | Loss: 0.6138 | Val Acc: 0.6274
# Epoch 19 | Loss: 0.5895 | Val Acc: 0.6158
# Epoch 20 | Loss: 0.5751 | Val Acc: 0.5911
# Epoch 21 | Loss: 0.5574 | Val Acc: 0.6377
# Epoch 22 | Loss: 0.5291 | Val Acc: 0.6115
# Epoch 23 | Loss: 0.5219 | Val Acc: 0.6640
# Epoch 24 | Loss: 0.4994 | Val Acc: 0.6581
# Epoch 25 | Loss: 0.4915 | Val Acc: 0.6874
# Epoch 26 | Loss: 0.4770 | Val Acc: 0.6149
# Epoch 27 | Loss: 0.4703 | Val Acc: 0.6963
# Epoch 28 | Loss: 0.4466 | Val Acc: 0.7199
# Epoch 29 | Loss: 0.4363 | Val Acc: 0.7048
# Epoch 30 | Loss: 0.4341 | Val Acc: 0.7007
# Epoch 31 | Loss: 0.4183 | Val Acc: 0.6749
# Epoch 32 | Loss: 0.4033 | Val Acc: 0.7239
# Epoch 33 | Loss: 0.4041 | Val Acc: 0.7016
# Epoch 34 | Loss: 0.3967 | Val Acc: 0.6634
# Epoch 35 | Loss: 0.3821 | Val Acc: 0.7099
# Epoch 36 | Loss: 0.3782 | Val Acc: 0.7053
# Epoch 37 | Loss: 0.3715 | Val Acc: 0.6048
# Epoch 38 | Loss: 0.3595 | Val Acc: 0.7185
# Epoch 39 | Loss: 0.3536 | Val Acc: 0.7019
# Epoch 40 | Loss: 0.3517 | Val Acc: 0.6864
# Epoch 41 | Loss: 0.3480 | Val Acc: 0.6362
# Epoch 42 | Loss: 0.3382 | Val Acc: 0.7399
# Epoch 43 | Loss: 0.3495 | Val Acc: 0.7220
# Epoch 44 | Loss: 0.3208 | Val Acc: 0.7211
# Epoch 45 | Loss: 0.3316 | Val Acc: 0.6871
# Epoch 46 | Loss: 0.3225 | Val Acc: 0.7776
# Epoch 47 | Loss: 0.3109 | Val Acc: 0.7280
# Epoch 48 | Loss: 0.3210 | Val Acc: 0.8002
# Epoch 49 | Loss: 0.3160 | Val Acc: 0.7441
# Epoch 50 | Loss: 0.3031 | Val Acc: 0.7614
# Epoch 51 | Loss: 0.2890 | Val Acc: 0.7520
# Epoch 52 | Loss: 0.3046 | Val Acc: 0.7659
# Epoch 53 | Loss: 0.2920 | Val Acc: 0.7474
# Epoch 54 | Loss: 0.2764 | Val Acc: 0.6881
# Epoch 55 | Loss: 0.2881 | Val Acc: 0.7331
# Epoch 56 | Loss: 0.2691 | Val Acc: 0.7352
# Epoch 57 | Loss: 0.2845 | Val Acc: 0.8006
# Epoch 58 | Loss: 0.2854 | Val Acc: 0.7266
# Epoch 59 | Loss: 0.2748 | Val Acc: 0.7282
# Epoch 60 | Loss: 0.2645 | Val Acc: 0.7335
# Epoch 61 | Loss: 0.2599 | Val Acc: 0.7797
# Epoch 62 | Loss: 0.2533 | Val Acc: 0.7654
# Epoch 63 | Loss: 0.2639 | Val Acc: 0.7786
# Epoch 64 | Loss: 0.2654 | Val Acc: 0.7369
# Epoch 65 | Loss: 0.2466 | Val Acc: 0.8025
# Epoch 66 | Loss: 0.2446 | Val Acc: 0.7727
# Epoch 67 | Loss: 0.2782 | Val Acc: 0.7595
# Epoch 68 | Loss: 0.2427 | Val Acc: 0.7904
# Epoch 69 | Loss: 0.2427 | Val Acc: 0.7452
# Epoch 70 | Loss: 0.2476 | Val Acc: 0.7729
# Epoch 71 | Loss: 0.2484 | Val Acc: 0.7708
# Epoch 72 | Loss: 0.2287 | Val Acc: 0.7667
# Epoch 73 | Loss: 0.2609 | Val Acc: 0.7492
# Epoch 74 | Loss: 0.2432 | Val Acc: 0.7765
# Epoch 75 | Loss: 0.2317 | Val Acc: 0.7840
# Epoch 76 | Loss: 0.2481 | Val Acc: 0.8045
# Epoch 77 | Loss: 0.2374 | Val Acc: 0.7654
# Epoch 78 | Loss: 0.2226 | Val Acc: 0.7347
# Epoch 79 | Loss: 0.2287 | Val Acc: 0.7930
# Epoch 80 | Loss: 0.2222 | Val Acc: 0.8305
# Epoch 81 | Loss: 0.2186 | Val Acc: 0.8018
# Epoch 82 | Loss: 0.2274 | Val Acc: 0.7746
# Epoch 83 | Loss: 0.2268 | Val Acc: 0.8351
# Epoch 84 | Loss: 0.2189 | Val Acc: 0.7848
# Epoch 85 | Loss: 0.2335 | Val Acc: 0.7598
# Epoch 86 | Loss: 0.2111 | Val Acc: 0.7738
# Epoch 87 | Loss: 0.2205 | Val Acc: 0.7789
# Epoch 88 | Loss: 0.2309 | Val Acc: 0.7798
# Epoch 89 | Loss: 0.2110 | Val Acc: 0.7509
# Epoch 90 | Loss: 0.2185 | Val Acc: 0.7807
# Epoch 91 | Loss: 0.2229 | Val Acc: 0.7882
# Epoch 92 | Loss: 0.2322 | Val Acc: 0.7727
# Epoch 93 | Loss: 0.1945 | Val Acc: 0.7955
# Epoch 94 | Loss: 0.2109 | Val Acc: 0.8331
# Epoch 95 | Loss: 0.1968 | Val Acc: 0.7725
# Epoch 96 | Loss: 0.2384 | Val Acc: 0.7967
# Epoch 97 | Loss: 0.2127 | Val Acc: 0.7686
# Epoch 98 | Loss: 0.2071 | Val Acc: 0.7756
# Epoch 99 | Loss: 0.2089 | Val Acc: 0.7344
# Epoch 100 | Loss: 0.2035 | Val Acc: 0.7875
# Epoch 101 | Loss: 0.2118 | Val Acc: 0.8317
# Epoch 102 | Loss: 0.2061 | Val Acc: 0.7892
# Epoch 103 | Loss: 0.1868 | Val Acc: 0.8317
# Epoch 104 | Loss: 0.2072 | Val Acc: 0.8319
# Epoch 105 | Loss: 0.2001 | Val Acc: 0.7810
# Epoch 106 | Loss: 0.1898 | Val Acc: 0.8032
# Epoch 107 | Loss: 0.2009 | Val Acc: 0.8102
# Epoch 108 | Loss: 0.1885 | Val Acc: 0.7687
# Epoch 109 | Loss: 0.1820 | Val Acc: 0.8428
# Epoch 110 | Loss: 0.1906 | Val Acc: 0.7987
# Epoch 111 | Loss: 0.2121 | Val Acc: 0.7352
# Epoch 112 | Loss: 0.1896 | Val Acc: 0.7428
# Epoch 113 | Loss: 0.1923 | Val Acc: 0.7861
# Epoch 114 | Loss: 0.2035 | Val Acc: 0.7432
# Epoch 115 | Loss: 0.1957 | Val Acc: 0.7586
# Epoch 116 | Loss: 0.1880 | Val Acc: 0.7970
# Epoch 117 | Loss: 0.1834 | Val Acc: 0.8461
# Epoch 118 | Loss: 0.1938 | Val Acc: 0.7713
# Epoch 119 | Loss: 0.1941 | Val Acc: 0.8091
# Epoch 120 | Loss: 0.1928 | Val Acc: 0.8057
# Epoch 121 | Loss: 0.1791 | Val Acc: 0.7789
# Epoch 122 | Loss: 0.1803 | Val Acc: 0.7648
# Epoch 123 | Loss: 0.1905 | Val Acc: 0.8433
# Epoch 124 | Loss: 0.1826 | Val Acc: 0.8102
# Epoch 125 | Loss: 0.1834 | Val Acc: 0.8194
# Epoch 126 | Loss: 0.1834 | Val Acc: 0.8344
# Epoch 127 | Loss: 0.2154 | Val Acc: 0.7887
# Epoch 128 | Loss: 0.1671 | Val Acc: 0.8356
# Epoch 129 | Loss: 0.1917 | Val Acc: 0.7943
# Epoch 130 | Loss: 0.1787 | Val Acc: 0.7944
# Epoch 131 | Loss: 0.1988 | Val Acc: 0.8390
# Epoch 132 | Loss: 0.1692 | Val Acc: 0.7577
# Epoch 133 | Loss: 0.1870 | Val Acc: 0.8133
# Epoch 134 | Loss: 0.1654 | Val Acc: 0.7852
# Epoch 135 | Loss: 0.1964 | Val Acc: 0.7544
# Epoch 136 | Loss: 0.1913 | Val Acc: 0.8234
# Epoch 137 | Loss: 0.1591 | Val Acc: 0.7896
# Epoch 138 | Loss: 0.1806 | Val Acc: 0.7653
# Epoch 139 | Loss: 0.1841 | Val Acc: 0.8423
# Epoch 140 | Loss: 0.1616 | Val Acc: 0.8122
# Epoch 141 | Loss: 0.1727 | Val Acc: 0.7926
# Epoch 142 | Loss: 0.1828 | Val Acc: 0.7765
# Epoch 143 | Loss: 0.1756 | Val Acc: 0.8085
# Epoch 144 | Loss: 0.1858 | Val Acc: 0.7828
# Epoch 145 | Loss: 0.1825 | Val Acc: 0.8062
# Epoch 146 | Loss: 0.1771 | Val Acc: 0.8504
# Epoch 147 | Loss: 0.1815 | Val Acc: 0.8093
# Epoch 148 | Loss: 0.1588 | Val Acc: 0.7930
# Epoch 149 | Loss: 0.1748 | Val Acc: 0.8351
# Epoch 150 | Loss: 0.1698 | Val Acc: 0.8101
# Epoch 151 | Loss: 0.1705 | Val Acc: 0.7533
# Epoch 152 | Loss: 0.1821 | Val Acc: 0.8413
# Epoch 153 | Loss: 0.1575 | Val Acc: 0.7537
# Epoch 154 | Loss: 0.1812 | Val Acc: 0.7782
# Epoch 155 | Loss: 0.1672 | Val Acc: 0.8500
# Epoch 156 | Loss: 0.1612 | Val Acc: 0.8270
# Epoch 157 | Loss: 0.1644 | Val Acc: 0.7757
# Epoch 158 | Loss: 0.1767 | Val Acc: 0.8063
# Epoch 159 | Loss: 0.1624 | Val Acc: 0.8268
# Epoch 160 | Loss: 0.1603 | Val Acc: 0.7703
# Epoch 161 | Loss: 0.1740 | Val Acc: 0.8185
# Epoch 162 | Loss: 0.1566 | Val Acc: 0.7909
# Epoch 163 | Loss: 0.1716 | Val Acc: 0.8031
# Epoch 164 | Loss: 0.1665 | Val Acc: 0.8461
# Epoch 165 | Loss: 0.1608 | Val Acc: 0.8231
# Epoch 166 | Loss: 0.1743 | Val Acc: 0.8146
# Epoch 167 | Loss: 0.1819 | Val Acc: 0.7872
# Epoch 168 | Loss: 0.1778 | Val Acc: 0.7942
# Epoch 169 | Loss: 0.1720 | Val Acc: 0.8174
# Epoch 170 | Loss: 0.1524 | Val Acc: 0.8400
# Epoch 171 | Loss: 0.1560 | Val Acc: 0.8003
# Epoch 172 | Loss: 0.1810 | Val Acc: 0.8163
# Epoch 173 | Loss: 0.1543 | Val Acc: 0.8176
# Epoch 174 | Loss: 0.1516 | Val Acc: 0.8288
# Epoch 175 | Loss: 0.1601 | Val Acc: 0.7980
# Epoch 176 | Loss: 0.1516 | Val Acc: 0.8191
# Epoch 177 | Loss: 0.1587 | Val Acc: 0.8072
# Epoch 178 | Loss: 0.1603 | Val Acc: 0.8468
# Epoch 179 | Loss: 0.1795 | Val Acc: 0.8072
# Epoch 180 | Loss: 0.1531 | Val Acc: 0.7841
# Epoch 181 | Loss: 0.1592 | Val Acc: 0.8097
# Epoch 182 | Loss: 0.1542 | Val Acc: 0.8053
# Epoch 183 | Loss: 0.1623 | Val Acc: 0.7865
# Epoch 184 | Loss: 0.1547 | Val Acc: 0.8190
# Epoch 185 | Loss: 0.1573 | Val Acc: 0.8229
# Epoch 186 | Loss: 0.1626 | Val Acc: 0.8014
# Epoch 187 | Loss: 0.1715 | Val Acc: 0.8231
# Epoch 188 | Loss: 0.1793 | Val Acc: 0.8191
# Epoch 189 | Loss: 0.1592 | Val Acc: 0.7914
# Epoch 190 | Loss: 0.1427 | Val Acc: 0.8041
# Epoch 191 | Loss: 0.1498 | Val Acc: 0.8187
# Epoch 192 | Loss: 0.1440 | Val Acc: 0.8029
# Epoch 193 | Loss: 0.1624 | Val Acc: 0.8321
# Epoch 194 | Loss: 0.1462 | Val Acc: 0.8236
# Epoch 195 | Loss: 0.1472 | Val Acc: 0.8300
# Epoch 196 | Loss: 0.1616 | Val Acc: 0.7930
# Epoch 197 | Loss: 0.1451 | Val Acc: 0.8356
# Epoch 198 | Loss: 0.1889 | Val Acc: 0.7522
# Epoch 199 | Loss: 0.1583 | Val Acc: 0.7896
# Epoch 200 | Loss: 0.1604 | Val Acc: 0.8019
# Epoch 201 | Loss: 0.1570 | Val Acc: 0.8172
# Epoch 202 | Loss: 0.1453 | Val Acc: 0.8180
# Epoch 203 | Loss: 0.1435 | Val Acc: 0.8542
# Epoch 204 | Loss: 0.1609 | Val Acc: 0.8366
# Epoch 205 | Loss: 0.1716 | Val Acc: 0.8297
# Epoch 206 | Loss: 0.1459 | Val Acc: 0.8523
# Epoch 207 | Loss: 0.1410 | Val Acc: 0.7984
# Epoch 208 | Loss: 0.1486 | Val Acc: 0.8453
# Epoch 209 | Loss: 0.1373 | Val Acc: 0.8224
# Epoch 210 | Loss: 0.1761 | Val Acc: 0.8042
# Epoch 211 | Loss: 0.1418 | Val Acc: 0.8359
# Epoch 212 | Loss: 0.1398 | Val Acc: 0.8505
# Epoch 213 | Loss: 0.1544 | Val Acc: 0.8577
# Epoch 214 | Loss: 0.1770 | Val Acc: 0.8228
# Epoch 215 | Loss: 0.1535 | Val Acc: 0.8321
# Epoch 216 | Loss: 0.1354 | Val Acc: 0.8211
# Epoch 217 | Loss: 0.1471 | Val Acc: 0.8245
# Epoch 218 | Loss: 0.1579 | Val Acc: 0.7930
# Epoch 219 | Loss: 0.1493 | Val Acc: 0.8216
# Epoch 220 | Loss: 0.1371 | Val Acc: 0.8331
# Epoch 221 | Loss: 0.1578 | Val Acc: 0.8400
# Epoch 222 | Loss: 0.1552 | Val Acc: 0.8377
# Epoch 223 | Loss: 0.1464 | Val Acc: 0.8214
# Epoch 224 | Loss: 0.1533 | Val Acc: 0.8187
# Epoch 225 | Loss: 0.1519 | Val Acc: 0.8211
# Epoch 226 | Loss: 0.1475 | Val Acc: 0.8331
# Epoch 227 | Loss: 0.1483 | Val Acc: 0.7772
# Epoch 228 | Loss: 0.1432 | Val Acc: 0.7990
# Epoch 229 | Loss: 0.1377 | Val Acc: 0.7820
# Epoch 230 | Loss: 0.1364 | Val Acc: 0.8458
# Epoch 231 | Loss: 0.1601 | Val Acc: 0.8241
# Epoch 232 | Loss: 0.1528 | Val Acc: 0.8070
# Epoch 233 | Loss: 0.1379 | Val Acc: 0.8016
# Epoch 234 | Loss: 0.1477 | Val Acc: 0.8233
# Epoch 235 | Loss: 0.1430 | Val Acc: 0.8173
# Epoch 236 | Loss: 0.1339 | Val Acc: 0.8206
# Epoch 237 | Loss: 0.1736 | Val Acc: 0.8152
# Epoch 238 | Loss: 0.1564 | Val Acc: 0.8062
# Epoch 239 | Loss: 0.1458 | Val Acc: 0.7367
# Epoch 240 | Loss: 0.1288 | Val Acc: 0.8276
# Epoch 241 | Loss: 0.1536 | Val Acc: 0.8244
# Epoch 242 | Loss: 0.1270 | Val Acc: 0.8156
# Epoch 243 | Loss: 0.1472 | Val Acc: 0.8045
# Epoch 244 | Loss: 0.1442 | Val Acc: 0.8383
# Epoch 245 | Loss: 0.1614 | Val Acc: 0.8406
# Epoch 246 | Loss: 0.1621 | Val Acc: 0.8116
# Epoch 247 | Loss: 0.1383 | Val Acc: 0.8428
# Epoch 248 | Loss: 0.1313 | Val Acc: 0.8084
# Epoch 249 | Loss: 0.1529 | Val Acc: 0.8263
# Epoch 250 | Loss: 0.1332 | Val Acc: 0.8002
# Epoch 251 | Loss: 0.1715 | Val Acc: 0.7956
# Epoch 252 | Loss: 0.1371 | Val Acc: 0.8599
# Epoch 253 | Loss: 0.1414 | Val Acc: 0.8194
# Epoch 254 | Loss: 0.1387 | Val Acc: 0.8225
# Epoch 255 | Loss: 0.1330 | Val Acc: 0.8165
# Epoch 256 | Loss: 0.1486 | Val Acc: 0.8659
# Epoch 257 | Loss: 0.1560 | Val Acc: 0.8232
# Epoch 258 | Loss: 0.1369 | Val Acc: 0.8102
# Epoch 259 | Loss: 0.1457 | Val Acc: 0.8329
# Epoch 260 | Loss: 0.1392 | Val Acc: 0.8049
# Epoch 261 | Loss: 0.1500 | Val Acc: 0.8100
# Epoch 262 | Loss: 0.1562 | Val Acc: 0.8412
# Epoch 263 | Loss: 0.1535 | Val Acc: 0.8206
# Epoch 264 | Loss: 0.1463 | Val Acc: 0.8084
# Epoch 265 | Loss: 0.1332 | Val Acc: 0.8332
# Epoch 266 | Loss: 0.1276 | Val Acc: 0.8359
# Epoch 267 | Loss: 0.1310 | Val Acc: 0.8595
# Epoch 268 | Loss: 0.1575 | Val Acc: 0.7931
# Epoch 269 | Loss: 0.1643 | Val Acc: 0.8353
# Epoch 270 | Loss: 0.1329 | Val Acc: 0.8248
# Epoch 271 | Loss: 0.1361 | Val Acc: 0.7875
# Epoch 272 | Loss: 0.1355 | Val Acc: 0.8153
# Epoch 273 | Loss: 0.1391 | Val Acc: 0.8231
# Epoch 274 | Loss: 0.1362 | Val Acc: 0.8293
# Epoch 275 | Loss: 0.1407 | Val Acc: 0.8216
# Epoch 276 | Loss: 0.1412 | Val Acc: 0.8425
# Epoch 277 | Loss: 0.1491 | Val Acc: 0.8219
# Epoch 278 | Loss: 0.1303 | Val Acc: 0.8220
# Epoch 279 | Loss: 0.1432 | Val Acc: 0.8225
# Epoch 280 | Loss: 0.1297 | Val Acc: 0.8155
# Epoch 281 | Loss: 0.1416 | Val Acc: 0.8398
# Epoch 282 | Loss: 0.1322 | Val Acc: 0.8577
# Epoch 283 | Loss: 0.1327 | Val Acc: 0.8189
# Epoch 284 | Loss: 0.1545 | Val Acc: 0.7836
# Epoch 285 | Loss: 0.1488 | Val Acc: 0.8148
# Epoch 286 | Loss: 0.1278 | Val Acc: 0.8253
# Epoch 287 | Loss: 0.1388 | Val Acc: 0.8231
# Epoch 288 | Loss: 0.1299 | Val Acc: 0.8343
# Epoch 289 | Loss: 0.1582 | Val Acc: 0.8241
# Epoch 290 | Loss: 0.1253 | Val Acc: 0.7921
# Epoch 291 | Loss: 0.1328 | Val Acc: 0.8207
# Epoch 292 | Loss: 0.1347 | Val Acc: 0.8265
# Epoch 293 | Loss: 0.1283 | Val Acc: 0.8063
# Epoch 294 | Loss: 0.1478 | Val Acc: 0.7893
# Epoch 295 | Loss: 0.1466 | Val Acc: 0.8016
# Epoch 296 | Loss: 0.1371 | Val Acc: 0.8198
# Epoch 297 | Loss: 0.1290 | Val Acc: 0.8007
# Epoch 298 | Loss: 0.1257 | Val Acc: 0.8240
# Epoch 299 | Loss: 0.1600 | Val Acc: 0.8364
# Epoch 300 | Loss: 0.1478 | Val Acc: 0.8274
# 📊 Final Classification Report:
#               precision    recall  f1-score   support
#
#      Stage 0       0.72      0.71      0.72       642
#      Stage 1       0.64      0.79      0.71      1436
#      Stage 2       0.91      0.86      0.88      5115
#      Stage 3       0.85      0.69      0.76       459
#
#     accuracy                           0.83      7652
#    macro avg       0.78      0.77      0.77      7652
# weighted avg       0.84      0.83      0.83      7652

# %%
# === Imports ===
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

# === Config ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 64
EPOCHS = 200
LR = 1e-4
NUM_CLASSES = 4

# === Load Data ===
data = torch.load("data/esm2_delta_embeddings.pt")
X = data['X']
y = data['y']

# Fix shape if needed
if X.ndim == 3 and X.shape[1] == 1:
    X = X.squeeze(1)

# === Tokenization sweep ===
token_options = [2, 4, 5, 8, 10]  # choose values that divide X.shape[1]

results = {}
all_losses = {}
all_accuracies = {}

for T in token_options:
    assert X.shape[1] % T == 0, f"Token count {T} must divide embedding dim {X.shape[1]}"
    D = X.shape[1] // T

    # Reshape
    X_reshaped = X.reshape(-1, T, D)
    X_train, X_val, y_train, y_val = train_test_split(X_reshaped, y, test_size=0.2, stratify=y, random_state=42)

    # Dataset
    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

    # Weights
    class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_train.numpy()), y=y_train.numpy())
    class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)

    # Model
    class TransformerClassifier(nn.Module):
        def __init__(self, dim, heads=4, ff_dim=256, num_classes=4, dropout=0.1):
            super().__init__()
            encoder_layer = nn.TransformerEncoderLayer(d_model=dim, nhead=heads, dim_feedforward=ff_dim, dropout=dropout, batch_first=True)
            self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=2)
            self.classifier = nn.Sequential(
                nn.LayerNorm(dim),
                nn.Linear(dim, num_classes)
            )

        def forward(self, x):
            x = self.encoder(x)
            x = x.mean(dim=1)
            return self.classifier(x)

    model = TransformerClassifier(dim=D, num_classes=NUM_CLASSES).to(device)
    optimizer = optim.AdamW(model.parameters(), lr=LR)
    loss_fn = nn.CrossEntropyLoss(weight=class_weights)

    best_acc = 0.0
    epoch_losses = []
    epoch_accuracies = []

    for epoch in range(1, EPOCHS+1):
        model.train()
        total_loss = 0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            out = model(xb)
            loss = loss_fn(out, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        epoch_losses.append(total_loss / len(train_loader))

        # === Validation ===
        model.eval()
        all_preds, all_labels = [], []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb = xb.to(device)
                preds = model(xb).argmax(dim=1).cpu()
                all_preds.extend(preds)
                all_labels.extend(yb)
        acc = accuracy_score(all_labels, all_preds)
        epoch_accuracies.append(acc)
        best_acc = max(best_acc, acc)
        # print every 10 epochs
        if epoch % 20 == 0 or epoch == EPOCHS:
            print(f"[Tokens={T}] Epoch {epoch:2d} | Loss: {epoch_losses[-1]:.4f} | Val Acc: {acc:.4f}")
            
    results[T] = best_acc
    all_losses[T] = epoch_losses
    all_accuracies[T] = epoch_accuracies
    print(f"[Tokens={T}] Best Val Accuracy: {best_acc:.4f}")

# === Summary Plot ===
print("\n📊 Accuracy by Token Count:")
for k, v in results.items():
    print(f"{k} tokens: {v:.4f}")

# Plot Loss curves
plt.figure(figsize=(14, 5))
for T in token_options:
    plt.plot(all_losses[T], label=f"Tokens={T}")
plt.title("Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot Accuracy curves
plt.figure(figsize=(14, 5))
for T in token_options:
    plt.plot(all_accuracies[T], label=f"Tokens={T}")
plt.title("Validation Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot Token Count vs Best Accuracy
plt.figure(figsize=(6, 5))
plt.plot(list(results.keys()), list(results.values()), marker='o', color='purple')
plt.title("Best Accuracy vs Token Count")
plt.xlabel("Token Count")
plt.ylabel("Best Validation Accuracy")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [Tokens=2] Epoch 20 | Loss: 0.4485 | Val Acc: 0.6545
# [Tokens=2] Epoch 40 | Loss: 0.2807 | Val Acc: 0.7848
# [Tokens=2] Epoch 60 | Loss: 0.2703 | Val Acc: 0.7910
# [Tokens=2] Epoch 80 | Loss: 0.2335 | Val Acc: 0.7795
# [Tokens=2] Epoch 100 | Loss: 0.2010 | Val Acc: 0.7547
# [Tokens=2] Epoch 120 | Loss: 0.1895 | Val Acc: 0.8177
# [Tokens=2] Epoch 140 | Loss: 0.1949 | Val Acc: 0.8312
# [Tokens=2] Epoch 160 | Loss: 0.1771 | Val Acc: 0.8271
# [Tokens=2] Epoch 180 | Loss: 0.1900 | Val Acc: 0.8255
# [Tokens=2] Epoch 200 | Loss: 0.1622 | Val Acc: 0.8180
# [Tokens=2] Best Val Accuracy: 0.8627
# [Tokens=4] Epoch 20 | Loss: 0.5565 | Val Acc: 0.6367
# [Tokens=4] Epoch 40 | Loss: 0.3413 | Val Acc: 0.6482
# [Tokens=4] Epoch 60 | Loss: 0.2589 | Val Acc: 0.7629
# [Tokens=4] Epoch 80 | Loss: 0.2135 | Val Acc: 0.8130
# [Tokens=4] Epoch 100 | Loss: 0.2131 | Val Acc: 0.7995
# [Tokens=4] Epoch 120 | Loss: 0.1854 | Val Acc: 0.7816
# [Tokens=4] Epoch 140 | Loss: 0.1735 | Val Acc: 0.8102
# [Tokens=4] Epoch 160 | Loss: 0.1638 | Val Acc: 0.8129
# [Tokens=4] Epoch 180 | Loss: 0.1533 | Val Acc: 0.8495
# [Tokens=4] Epoch 200 | Loss: 0.1537 | Val Acc: 0.8227
# [Tokens=4] Best Val Accuracy: 0.8581
# [Tokens=5] Epoch 20 | Loss: 0.6201 | Val Acc: 0.5434
# [Tokens=5] Epoch 40 | Loss: 0.3817 | Val Acc: 0.7163
# [Tokens=5] Epoch 60 | Loss: 0.2842 | Val Acc: 0.8025
# [Tokens=5] Epoch 80 | Loss: 0.2314 | Val Acc: 0.7977
# [Tokens=5] Epoch 100 | Loss: 0.2204 | Val Acc: 0.7938
# [Tokens=5] Epoch 120 | Loss: 0.1993 | Val Acc: 0.8108
# [Tokens=5] Epoch 140 | Loss: 0.1781 | Val Acc: 0.7307
# [Tokens=5] Epoch 160 | Loss: 0.1687 | Val Acc: 0.7705
# [Tokens=5] Epoch 180 | Loss: 0.1588 | Val Acc: 0.8484
# [Tokens=5] Epoch 200 | Loss: 0.1630 | Val Acc: 0.8509
# [Tokens=5] Best Val Accuracy: 0.8509
# [Tokens=8] Epoch 20 | Loss: 0.8684 | Val Acc: 0.4463
# [Tokens=8] Epoch 40 | Loss: 0.5665 | Val Acc: 0.5644
# [Tokens=8] Epoch 60 | Loss: 0.4030 | Val Acc: 0.6383
# [Tokens=8] Epoch 80 | Loss: 0.3100 | Val Acc: 0.7680
# [Tokens=8] Epoch 100 | Loss: 0.2640 | Val Acc: 0.7237
# [Tokens=8] Epoch 120 | Loss: 0.2396 | Val Acc: 0.7389
# [Tokens=8] Epoch 140 | Loss: 0.1958 | Val Acc: 0.7563
# [Tokens=8] Epoch 160 | Loss: 0.1926 | Val Acc: 0.7901
# [Tokens=8] Epoch 180 | Loss: 0.1618 | Val Acc: 0.8084
# [Tokens=8] Epoch 200 | Loss: 0.1772 | Val Acc: 0.8240
# [Tokens=8] Best Val Accuracy: 0.8387
# [Tokens=10] Epoch 20 | Loss: 0.9927 | Val Acc: 0.3987
# [Tokens=10] Epoch 40 | Loss: 0.6862 | Val Acc: 0.5374
# [Tokens=10] Epoch 60 | Loss: 0.4976 | Val Acc: 0.6091
# [Tokens=10] Epoch 80 | Loss: 0.3936 | Val Acc: 0.6943
# [Tokens=10] Epoch 100 | Loss: 0.3153 | Val Acc: 0.7369
# [Tokens=10] Epoch 120 | Loss: 0.2650 | Val Acc: 0.7488
# [Tokens=10] Epoch 140 | Loss: 0.2329 | Val Acc: 0.7731
# [Tokens=10] Epoch 160 | Loss: 0.2109 | Val Acc: 0.7808
# [Tokens=10] Epoch 180 | Loss: 0.1947 | Val Acc: 0.7857
# [Tokens=10] Epoch 200 | Loss: 0.1758 | Val Acc: 0.8125
# [Tokens=10] Best Val Accuracy: 0.8297
#
# 📊 Accuracy by Token Count:
# 2 tokens: 0.8627
# 4 tokens: 0.8581
# 5 tokens: 0.8509
# 8 tokens: 0.8387
# 10 tokens: 0.8297

# %%
plt.style.use('default')
# === Summary Plot ===
print("\n📊 Accuracy by Token Count:")
for k, v in results.items():
    print(f"{k} tokens: {v:.4f}")

# Plot Loss curves
plt.figure(figsize=(10, 5))
for T in token_options:
    plt.plot(all_losses[T], label=f"Tokens={T}")
plt.title("Loss vs Epoch", fontsize=20)
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Training Loss", fontsize=18)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot Accuracy curves
plt.figure(figsize=(10, 5))
for T in token_options:
    plt.plot(all_accuracies[T], label=f"Tokens={T}")
plt.title("Validation Accuracy vs Epoch", fontsize=20)
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Validation Accuracy", fontsize=18)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot Token Count vs Best Accuracy
plt.figure(figsize=(6, 5))
plt.plot(list(results.keys()), list(results.values()), marker='o', color='purple')
plt.title("Best Accuracy vs Token Count", fontsize=20)
plt.xlabel("Token Count", fontsize=18)
plt.ylabel("Best Validation Accuracy", fontsize=18)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 📊 Accuracy by Token Count:
# 2 tokens: 0.8627
# 4 tokens: 0.8581
# 5 tokens: 0.8509
# 8 tokens: 0.8387
# 10 tokens: 0.8297

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import os

# === Config ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 64
EPOCHS = 300
LR = 1e-4
NUM_CLASSES = 4

# === Load Data ===
data = torch.load("data/esm2_embeddings.pt")
X = data['X']
if X.ndim == 3 and X.shape[1] == 1:
    X = X.squeeze(1)
y = data['y']

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# === Reshape to [B, T, D]
T = 4
D = X.shape[1] // T
X_train = X_train.reshape(-1, T, D)
X_val = X_val.reshape(-1, T, D)

# === DataLoader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# === Class weights
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_train.numpy()), y=y_train.numpy())
class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)

# === Transformer Classifier
class TransformerClassifier(nn.Module):
    def __init__(self, dim, heads=4, ff_dim=256, num_classes=4, dropout=0.1):
        super().__init__()
        encoder_layer = nn.TransformerEncoderLayer(d_model=dim, nhead=heads, dim_feedforward=ff_dim, dropout=dropout, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=2)
        self.classifier = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = x.mean(dim=1)  # Global average pooling
        return self.classifier(x)

model = TransformerClassifier(dim=D, num_classes=NUM_CLASSES).to(device)
optimizer = optim.AdamW(model.parameters(), lr=LR)
loss_fn = nn.CrossEntropyLoss(weight=class_weights)

# === Train loop
train_losses, val_accuracies = [], []

for epoch in range(1, EPOCHS+1):
    model.train()
    total_loss = 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        out = model(xb)
        loss = loss_fn(out, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    train_losses.append(total_loss / len(train_loader))

    # === Validation
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for xb, yb in val_loader:
            xb = xb.to(device)
            preds = model(xb).argmax(dim=1).cpu()
            all_preds.extend(preds)
            all_labels.extend(yb)
    acc = accuracy_score(all_labels, all_preds)
    val_accuracies.append(acc)
    print(f"Epoch {epoch:2d} | Loss: {train_losses[-1]:.4f} | Val Acc: {acc:.4f}")

# === Plot loss & accuracy
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Loss")
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.subplot(1, 2, 2)
plt.plot(val_accuracies, label="Val Acc", color="orange")
plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.tight_layout()
plt.show()

# === Final Evaluation
print("\n📊 Final Classification Report:")
print(classification_report(all_labels, all_preds, target_names=[f"Stage {i}" for i in range(NUM_CLASSES)]))
# Out:
# Epoch  1 | Loss: 1.3935 | Val Acc: 0.1790
# Epoch  2 | Loss: 1.3728 | Val Acc: 0.1752
# Epoch  3 | Loss: 1.3443 | Val Acc: 0.3556
# Epoch  4 | Loss: 1.2974 | Val Acc: 0.4046
# Epoch  5 | Loss: 1.2486 | Val Acc: 0.3163
# Epoch  6 | Loss: 1.1903 | Val Acc: 0.2903
# Epoch  7 | Loss: 1.1369 | Val Acc: 0.3257
# Epoch  8 | Loss: 1.0774 | Val Acc: 0.4694
# Epoch  9 | Loss: 1.0279 | Val Acc: 0.3710
# Epoch 10 | Loss: 0.9801 | Val Acc: 0.4799
# Epoch 11 | Loss: 0.9403 | Val Acc: 0.4178
# Epoch 12 | Loss: 0.8975 | Val Acc: 0.3911
# Epoch 13 | Loss: 0.8649 | Val Acc: 0.4698
# Epoch 14 | Loss: 0.8319 | Val Acc: 0.4675
# Epoch 15 | Loss: 0.8094 | Val Acc: 0.5119
# Epoch 16 | Loss: 0.7819 | Val Acc: 0.4850
# Epoch 17 | Loss: 0.7618 | Val Acc: 0.5178
# Epoch 18 | Loss: 0.7374 | Val Acc: 0.5165
# Epoch 19 | Loss: 0.7124 | Val Acc: 0.5289
# Epoch 20 | Loss: 0.6896 | Val Acc: 0.4890
# Epoch 21 | Loss: 0.6800 | Val Acc: 0.5536
# Epoch 22 | Loss: 0.6545 | Val Acc: 0.5263
# Epoch 23 | Loss: 0.6473 | Val Acc: 0.5344
# Epoch 24 | Loss: 0.6332 | Val Acc: 0.5403
# Epoch 25 | Loss: 0.6242 | Val Acc: 0.5542
# Epoch 26 | Loss: 0.6055 | Val Acc: 0.6127
# Epoch 27 | Loss: 0.5945 | Val Acc: 0.5717
# Epoch 28 | Loss: 0.5880 | Val Acc: 0.6321
# Epoch 29 | Loss: 0.5766 | Val Acc: 0.5746
# Epoch 30 | Loss: 0.5663 | Val Acc: 0.5818
# Epoch 31 | Loss: 0.5573 | Val Acc: 0.5987
# Epoch 32 | Loss: 0.5489 | Val Acc: 0.5708
# Epoch 33 | Loss: 0.5361 | Val Acc: 0.5983
# Epoch 34 | Loss: 0.5329 | Val Acc: 0.6115
# Epoch 35 | Loss: 0.5213 | Val Acc: 0.6228
# Epoch 36 | Loss: 0.5181 | Val Acc: 0.6272
# Epoch 37 | Loss: 0.5053 | Val Acc: 0.6141
# Epoch 38 | Loss: 0.5055 | Val Acc: 0.6154
# Epoch 39 | Loss: 0.5043 | Val Acc: 0.6047
# Epoch 40 | Loss: 0.4922 | Val Acc: 0.5993
# Epoch 41 | Loss: 0.4865 | Val Acc: 0.5998
# Epoch 42 | Loss: 0.4889 | Val Acc: 0.6236
# Epoch 43 | Loss: 0.4829 | Val Acc: 0.6055
# Epoch 44 | Loss: 0.4741 | Val Acc: 0.6449
# Epoch 45 | Loss: 0.4657 | Val Acc: 0.6397
# Epoch 46 | Loss: 0.4722 | Val Acc: 0.6411
# Epoch 47 | Loss: 0.4628 | Val Acc: 0.6179
# Epoch 48 | Loss: 0.4623 | Val Acc: 0.6368
# Epoch 49 | Loss: 0.4500 | Val Acc: 0.6405
# Epoch 50 | Loss: 0.4503 | Val Acc: 0.6289
# Epoch 51 | Loss: 0.4497 | Val Acc: 0.6221
# Epoch 52 | Loss: 0.4497 | Val Acc: 0.6498
# Epoch 53 | Loss: 0.4468 | Val Acc: 0.6372
# Epoch 54 | Loss: 0.4386 | Val Acc: 0.6342
# Epoch 55 | Loss: 0.4386 | Val Acc: 0.6462
# Epoch 56 | Loss: 0.4343 | Val Acc: 0.6542
# Epoch 57 | Loss: 0.4304 | Val Acc: 0.6401
# Epoch 58 | Loss: 0.4279 | Val Acc: 0.6381
# Epoch 59 | Loss: 0.4245 | Val Acc: 0.6513
# Epoch 60 | Loss: 0.4243 | Val Acc: 0.6268
# Epoch 61 | Loss: 0.4208 | Val Acc: 0.6194
# Epoch 62 | Loss: 0.4196 | Val Acc: 0.6336
# Epoch 63 | Loss: 0.4173 | Val Acc: 0.6637
# Epoch 64 | Loss: 0.4160 | Val Acc: 0.6392
# Epoch 65 | Loss: 0.4126 | Val Acc: 0.6563
# Epoch 66 | Loss: 0.4190 | Val Acc: 0.6555
# Epoch 67 | Loss: 0.4075 | Val Acc: 0.6554
# Epoch 68 | Loss: 0.4061 | Val Acc: 0.6494
# Epoch 69 | Loss: 0.4078 | Val Acc: 0.6485
# Epoch 70 | Loss: 0.4026 | Val Acc: 0.6479
# Epoch 71 | Loss: 0.4001 | Val Acc: 0.6554
# Epoch 72 | Loss: 0.4003 | Val Acc: 0.6281
# Epoch 73 | Loss: 0.3986 | Val Acc: 0.6447
# Epoch 74 | Loss: 0.3935 | Val Acc: 0.6658
# Epoch 75 | Loss: 0.3937 | Val Acc: 0.6481
# Epoch 76 | Loss: 0.3919 | Val Acc: 0.6478
# Epoch 77 | Loss: 0.3890 | Val Acc: 0.6411
# Epoch 78 | Loss: 0.3862 | Val Acc: 0.6620
# Epoch 79 | Loss: 0.3862 | Val Acc: 0.6394
# Epoch 80 | Loss: 0.3872 | Val Acc: 0.6560
# Epoch 81 | Loss: 0.3832 | Val Acc: 0.6635
# Epoch 82 | Loss: 0.3844 | Val Acc: 0.6583
# Epoch 83 | Loss: 0.3867 | Val Acc: 0.6521
# Epoch 84 | Loss: 0.3773 | Val Acc: 0.6522
# Epoch 85 | Loss: 0.3785 | Val Acc: 0.6564
# Epoch 86 | Loss: 0.3782 | Val Acc: 0.6653
# Epoch 87 | Loss: 0.3822 | Val Acc: 0.6708
# Epoch 88 | Loss: 0.3801 | Val Acc: 0.6688
# Epoch 89 | Loss: 0.3759 | Val Acc: 0.6669
# Epoch 90 | Loss: 0.3732 | Val Acc: 0.6426
# Epoch 91 | Loss: 0.3743 | Val Acc: 0.6606
# Epoch 92 | Loss: 0.3680 | Val Acc: 0.6622
# Epoch 93 | Loss: 0.3648 | Val Acc: 0.6623
# Epoch 94 | Loss: 0.3754 | Val Acc: 0.6515
# Epoch 95 | Loss: 0.3714 | Val Acc: 0.6647
# Epoch 96 | Loss: 0.3708 | Val Acc: 0.6583
# Epoch 97 | Loss: 0.3643 | Val Acc: 0.6528
# Epoch 98 | Loss: 0.3684 | Val Acc: 0.6543
# Epoch 99 | Loss: 0.3678 | Val Acc: 0.6539
# Epoch 100 | Loss: 0.3655 | Val Acc: 0.6607
# Epoch 101 | Loss: 0.3572 | Val Acc: 0.6634
# Epoch 102 | Loss: 0.3665 | Val Acc: 0.6605
# Epoch 103 | Loss: 0.3655 | Val Acc: 0.6737
# Epoch 104 | Loss: 0.3624 | Val Acc: 0.6590
# Epoch 105 | Loss: 0.3607 | Val Acc: 0.6671
# Epoch 106 | Loss: 0.3600 | Val Acc: 0.6658
# Epoch 107 | Loss: 0.3603 | Val Acc: 0.6720
# Epoch 108 | Loss: 0.3565 | Val Acc: 0.6656
# Epoch 109 | Loss: 0.3591 | Val Acc: 0.6671
# Epoch 110 | Loss: 0.3592 | Val Acc: 0.6647
# Epoch 111 | Loss: 0.3527 | Val Acc: 0.6651
# Epoch 112 | Loss: 0.3576 | Val Acc: 0.6579
# Epoch 113 | Loss: 0.3587 | Val Acc: 0.6620
# Epoch 114 | Loss: 0.3533 | Val Acc: 0.6743
# Epoch 115 | Loss: 0.3547 | Val Acc: 0.6775
# Epoch 116 | Loss: 0.3539 | Val Acc: 0.6654
# Epoch 117 | Loss: 0.3512 | Val Acc: 0.6715
# Epoch 118 | Loss: 0.3510 | Val Acc: 0.6559
# Epoch 119 | Loss: 0.3540 | Val Acc: 0.6662
# Epoch 120 | Loss: 0.3502 | Val Acc: 0.6644
# Epoch 121 | Loss: 0.3524 | Val Acc: 0.6526
# Epoch 122 | Loss: 0.3501 | Val Acc: 0.6643
# Epoch 123 | Loss: 0.3431 | Val Acc: 0.6579
# Epoch 124 | Loss: 0.3445 | Val Acc: 0.6754
# Epoch 125 | Loss: 0.3474 | Val Acc: 0.6588
# Epoch 126 | Loss: 0.3456 | Val Acc: 0.6577
# Epoch 127 | Loss: 0.3523 | Val Acc: 0.6588
# Epoch 128 | Loss: 0.3437 | Val Acc: 0.6572
# Epoch 129 | Loss: 0.3468 | Val Acc: 0.6639
# Epoch 130 | Loss: 0.3517 | Val Acc: 0.6662
# Epoch 131 | Loss: 0.3454 | Val Acc: 0.6705
# Epoch 132 | Loss: 0.3419 | Val Acc: 0.6587
# Epoch 133 | Loss: 0.3391 | Val Acc: 0.6614
# Epoch 134 | Loss: 0.3406 | Val Acc: 0.6588
# Epoch 135 | Loss: 0.3393 | Val Acc: 0.6555
# Epoch 136 | Loss: 0.3408 | Val Acc: 0.6632
# Epoch 137 | Loss: 0.3428 | Val Acc: 0.6457
# Epoch 138 | Loss: 0.3469 | Val Acc: 0.6529
# Epoch 139 | Loss: 0.3378 | Val Acc: 0.6570
# Epoch 140 | Loss: 0.3396 | Val Acc: 0.6503
# Epoch 141 | Loss: 0.3386 | Val Acc: 0.6695
# Epoch 142 | Loss: 0.3386 | Val Acc: 0.6716
# Epoch 143 | Loss: 0.3401 | Val Acc: 0.6739
# Epoch 144 | Loss: 0.3375 | Val Acc: 0.6507
# Epoch 145 | Loss: 0.3370 | Val Acc: 0.6606
# Epoch 146 | Loss: 0.3402 | Val Acc: 0.6656
# Epoch 147 | Loss: 0.3366 | Val Acc: 0.6623
# Epoch 148 | Loss: 0.3324 | Val Acc: 0.6657
# Epoch 149 | Loss: 0.3377 | Val Acc: 0.6589
# Epoch 150 | Loss: 0.3325 | Val Acc: 0.6525
# Epoch 151 | Loss: 0.3322 | Val Acc: 0.6669
# Epoch 152 | Loss: 0.3332 | Val Acc: 0.6640
# Epoch 153 | Loss: 0.3373 | Val Acc: 0.6622
# Epoch 154 | Loss: 0.3313 | Val Acc: 0.6743
# Epoch 155 | Loss: 0.3301 | Val Acc: 0.6556
# Epoch 156 | Loss: 0.3339 | Val Acc: 0.6788
# Epoch 157 | Loss: 0.3322 | Val Acc: 0.6711
# Epoch 158 | Loss: 0.3362 | Val Acc: 0.6601
# Epoch 159 | Loss: 0.3291 | Val Acc: 0.6767
# Epoch 160 | Loss: 0.3299 | Val Acc: 0.6721
# Epoch 161 | Loss: 0.3321 | Val Acc: 0.6658
# Epoch 162 | Loss: 0.3322 | Val Acc: 0.6648
# Epoch 163 | Loss: 0.3289 | Val Acc: 0.6677
# Epoch 164 | Loss: 0.3290 | Val Acc: 0.6749
# Epoch 165 | Loss: 0.3253 | Val Acc: 0.6631
# Epoch 166 | Loss: 0.3349 | Val Acc: 0.6699
# Epoch 167 | Loss: 0.3272 | Val Acc: 0.6622
# Epoch 168 | Loss: 0.3334 | Val Acc: 0.6669
# Epoch 169 | Loss: 0.3277 | Val Acc: 0.6585
# Epoch 170 | Loss: 0.3282 | Val Acc: 0.6729
# Epoch 171 | Loss: 0.3243 | Val Acc: 0.6688
# Epoch 172 | Loss: 0.3268 | Val Acc: 0.6568
# Epoch 173 | Loss: 0.3249 | Val Acc: 0.6696
# Epoch 174 | Loss: 0.3245 | Val Acc: 0.6741
# Epoch 175 | Loss: 0.3280 | Val Acc: 0.6720
# Epoch 176 | Loss: 0.3260 | Val Acc: 0.6726
# Epoch 177 | Loss: 0.3243 | Val Acc: 0.6644
# Epoch 178 | Loss: 0.3245 | Val Acc: 0.6653
# Epoch 179 | Loss: 0.3262 | Val Acc: 0.6648
# Epoch 180 | Loss: 0.3278 | Val Acc: 0.6756
# Epoch 181 | Loss: 0.3235 | Val Acc: 0.6725
# Epoch 182 | Loss: 0.3214 | Val Acc: 0.6708
# Epoch 183 | Loss: 0.3224 | Val Acc: 0.6615
# Epoch 184 | Loss: 0.3185 | Val Acc: 0.6662
# Epoch 185 | Loss: 0.3204 | Val Acc: 0.6640
# Epoch 186 | Loss: 0.3176 | Val Acc: 0.6664
# Epoch 187 | Loss: 0.3250 | Val Acc: 0.6656
# Epoch 188 | Loss: 0.3235 | Val Acc: 0.6517
# Epoch 189 | Loss: 0.3216 | Val Acc: 0.6596
# Epoch 190 | Loss: 0.3233 | Val Acc: 0.6813
# Epoch 191 | Loss: 0.3204 | Val Acc: 0.6779
# Epoch 192 | Loss: 0.3205 | Val Acc: 0.6648
# Epoch 193 | Loss: 0.3178 | Val Acc: 0.6577
# Epoch 194 | Loss: 0.3184 | Val Acc: 0.6749
# Epoch 195 | Loss: 0.3221 | Val Acc: 0.6707
# Epoch 196 | Loss: 0.3194 | Val Acc: 0.6673
# Epoch 197 | Loss: 0.3136 | Val Acc: 0.6682
# Epoch 198 | Loss: 0.3185 | Val Acc: 0.6692
# Epoch 199 | Loss: 0.3197 | Val Acc: 0.6683
# Epoch 200 | Loss: 0.3214 | Val Acc: 0.6657
# Epoch 201 | Loss: 0.3182 | Val Acc: 0.6626
# Epoch 202 | Loss: 0.3234 | Val Acc: 0.6559
# Epoch 203 | Loss: 0.3170 | Val Acc: 0.6661
# Epoch 204 | Loss: 0.3154 | Val Acc: 0.6720
# Epoch 205 | Loss: 0.3173 | Val Acc: 0.6665
# Epoch 206 | Loss: 0.3181 | Val Acc: 0.6716
# Epoch 207 | Loss: 0.3157 | Val Acc: 0.6587
# Epoch 208 | Loss: 0.3088 | Val Acc: 0.6775
# Epoch 209 | Loss: 0.3167 | Val Acc: 0.6635
# Epoch 210 | Loss: 0.3130 | Val Acc: 0.6691
# Epoch 211 | Loss: 0.3139 | Val Acc: 0.6524
# Epoch 212 | Loss: 0.3123 | Val Acc: 0.6768
# Epoch 213 | Loss: 0.3150 | Val Acc: 0.6682
# Epoch 214 | Loss: 0.3187 | Val Acc: 0.6822
# Epoch 215 | Loss: 0.3197 | Val Acc: 0.6656
# Epoch 216 | Loss: 0.3223 | Val Acc: 0.6615
# Epoch 217 | Loss: 0.3139 | Val Acc: 0.6671
# Epoch 218 | Loss: 0.3074 | Val Acc: 0.6741
# Epoch 219 | Loss: 0.3113 | Val Acc: 0.6597
# Epoch 220 | Loss: 0.3129 | Val Acc: 0.6675
# Epoch 221 | Loss: 0.3093 | Val Acc: 0.6698
# Epoch 222 | Loss: 0.3098 | Val Acc: 0.6636
# Epoch 223 | Loss: 0.3180 | Val Acc: 0.6645
# Epoch 224 | Loss: 0.3150 | Val Acc: 0.6776
# Epoch 225 | Loss: 0.3107 | Val Acc: 0.6713
# Epoch 226 | Loss: 0.3083 | Val Acc: 0.6564
# Epoch 227 | Loss: 0.3089 | Val Acc: 0.6719
# Epoch 228 | Loss: 0.3076 | Val Acc: 0.6585
# Epoch 229 | Loss: 0.3177 | Val Acc: 0.6597
# Epoch 230 | Loss: 0.3179 | Val Acc: 0.6589
# Epoch 231 | Loss: 0.3147 | Val Acc: 0.6653
# Epoch 232 | Loss: 0.3139 | Val Acc: 0.6632
# Epoch 233 | Loss: 0.3063 | Val Acc: 0.6687
# Epoch 234 | Loss: 0.3071 | Val Acc: 0.6707
# Epoch 235 | Loss: 0.3114 | Val Acc: 0.6739
# Epoch 236 | Loss: 0.3076 | Val Acc: 0.6703
# Epoch 237 | Loss: 0.3107 | Val Acc: 0.6734
# Epoch 238 | Loss: 0.3118 | Val Acc: 0.6699
# Epoch 239 | Loss: 0.3076 | Val Acc: 0.6619
# Epoch 240 | Loss: 0.3159 | Val Acc: 0.6670
# Epoch 241 | Loss: 0.3098 | Val Acc: 0.6584
# Epoch 242 | Loss: 0.3090 | Val Acc: 0.6702
# Epoch 243 | Loss: 0.3040 | Val Acc: 0.6764
# Epoch 244 | Loss: 0.3077 | Val Acc: 0.6742
# Epoch 245 | Loss: 0.3145 | Val Acc: 0.6579
# Epoch 246 | Loss: 0.3064 | Val Acc: 0.6767
# Epoch 247 | Loss: 0.3071 | Val Acc: 0.6550
# Epoch 248 | Loss: 0.3098 | Val Acc: 0.6725
# Epoch 249 | Loss: 0.3029 | Val Acc: 0.6719
# Epoch 250 | Loss: 0.3054 | Val Acc: 0.6800
# Epoch 251 | Loss: 0.3095 | Val Acc: 0.6702
# Epoch 252 | Loss: 0.3082 | Val Acc: 0.6737
# Epoch 253 | Loss: 0.3080 | Val Acc: 0.6598
# Epoch 254 | Loss: 0.3037 | Val Acc: 0.6609
# Epoch 255 | Loss: 0.3087 | Val Acc: 0.6611
# Epoch 256 | Loss: 0.3062 | Val Acc: 0.6725
# Epoch 257 | Loss: 0.3092 | Val Acc: 0.6741
# Epoch 258 | Loss: 0.3019 | Val Acc: 0.6615
# Epoch 259 | Loss: 0.3022 | Val Acc: 0.6771
# Epoch 260 | Loss: 0.3035 | Val Acc: 0.6687
# Epoch 261 | Loss: 0.3063 | Val Acc: 0.6632
# Epoch 262 | Loss: 0.3055 | Val Acc: 0.6630
# Epoch 263 | Loss: 0.3050 | Val Acc: 0.6627
# Epoch 264 | Loss: 0.3067 | Val Acc: 0.6652
# Epoch 265 | Loss: 0.3035 | Val Acc: 0.6674
# Epoch 266 | Loss: 0.3070 | Val Acc: 0.6751
# Epoch 267 | Loss: 0.3009 | Val Acc: 0.6681
# Epoch 268 | Loss: 0.3177 | Val Acc: 0.6643
# Epoch 269 | Loss: 0.3049 | Val Acc: 0.6729
# Epoch 270 | Loss: 0.3007 | Val Acc: 0.6692
# Epoch 271 | Loss: 0.3061 | Val Acc: 0.6587
# Epoch 272 | Loss: 0.3012 | Val Acc: 0.6699
# Epoch 273 | Loss: 0.3048 | Val Acc: 0.6665
# Epoch 274 | Loss: 0.3057 | Val Acc: 0.6628
# Epoch 275 | Loss: 0.3013 | Val Acc: 0.6670
# Epoch 276 | Loss: 0.3009 | Val Acc: 0.6708
# Epoch 277 | Loss: 0.3075 | Val Acc: 0.6636
# Epoch 278 | Loss: 0.3078 | Val Acc: 0.6763
# Epoch 279 | Loss: 0.3005 | Val Acc: 0.6768
# Epoch 280 | Loss: 0.3002 | Val Acc: 0.6772
# Epoch 281 | Loss: 0.3049 | Val Acc: 0.6675
# Epoch 282 | Loss: 0.3008 | Val Acc: 0.6688
# Epoch 283 | Loss: 0.3112 | Val Acc: 0.6652
# Epoch 284 | Loss: 0.3042 | Val Acc: 0.6711
# Epoch 285 | Loss: 0.3017 | Val Acc: 0.6675
# Epoch 286 | Loss: 0.2987 | Val Acc: 0.6769
# Epoch 287 | Loss: 0.3009 | Val Acc: 0.6819
# Epoch 288 | Loss: 0.2968 | Val Acc: 0.6647
# Epoch 289 | Loss: 0.2976 | Val Acc: 0.6717
# Epoch 290 | Loss: 0.3034 | Val Acc: 0.6592
# Epoch 291 | Loss: 0.2999 | Val Acc: 0.6554
# Epoch 292 | Loss: 0.3057 | Val Acc: 0.6685
# Epoch 293 | Loss: 0.3008 | Val Acc: 0.6610
# Epoch 294 | Loss: 0.3020 | Val Acc: 0.6620
# Epoch 295 | Loss: 0.3027 | Val Acc: 0.6709
# Epoch 296 | Loss: 0.3027 | Val Acc: 0.6674
# Epoch 297 | Loss: 0.2947 | Val Acc: 0.6686
# Epoch 298 | Loss: 0.2989 | Val Acc: 0.6690
# Epoch 299 | Loss: 0.3009 | Val Acc: 0.6762
# Epoch 300 | Loss: 0.3029 | Val Acc: 0.6729
# 📊 Final Classification Report:
#               precision    recall  f1-score   support
#
#      Stage 0       0.42      0.66      0.52       642
#      Stage 1       0.50      0.60      0.54      1436
#      Stage 2       0.86      0.70      0.77      5115
#      Stage 3       0.38      0.63      0.47       459
#
#     accuracy                           0.67      7652
#    macro avg       0.54      0.65      0.58      7652
# weighted avg       0.73      0.67      0.69      7652

# %% [markdown]
# ## Clinical

# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from torch.utils.data import TensorDataset, DataLoader

# === Read Data ===
df = pd.read_csv("data/cancer_data_preprocessed.csv")
print("✅ Data loaded. Shape:", df.shape)

# === Select and Encode Features ===
features = ["Cancer Type", "Donor Age at Diagnosis", "Donor Sex", "Histology Abbreviation"]
target = "Cancer Stage"

# Label encode categorical features
cat_features = ["Cancer Type", "Donor Sex", "Histology Abbreviation"]
encoders = {}
for col in cat_features:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le

# Standardize age
scaler = StandardScaler()
df["Donor Age at Diagnosis"] = scaler.fit_transform(df[["Donor Age at Diagnosis"]])

# Label encode target
label_encoder = LabelEncoder()
df["label"] = label_encoder.fit_transform(df[target])
NUM_CLASSES = len(label_encoder.classes_)
print(f"🔢 Stage classes: {label_encoder.classes_.tolist()}")

# === Convert to Tensor Format ===
X = torch.tensor(df[features].values, dtype=torch.float32)
y = torch.tensor(df["label"].values)

# Reshape to [B, T, D] for transformer
T = 1
D = X.shape[1]
X = X.view(-1, T, D)

# === Train/Val Split ===
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=64, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=64)

print(f"📐 Data shape for Transformer: {X.shape}, num_classes={NUM_CLASSES}")
# Out:
# ✅ Data loaded. Shape: (38258, 10)
# 🔢 Stage classes: [1, 2, 3, 4]
# 📐 Data shape for Transformer: torch.Size([38258, 1, 4]), num_classes=4

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder
import matplotlib.pyplot as plt

# === Config ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DATA_PATH = "data/cancer_data_preprocessed.csv"
BATCH_SIZE = 64
EPOCHS = 300
LR = 1e-4
NUM_CLASSES = 4

# === Load CSV ===
df = pd.read_csv(DATA_PATH)
df = df[["Cancer Type", "Donor Age at Diagnosis", "Donor Sex", "Histology Abbreviation", "Cancer Stage"]].dropna()

# === Encode categorical features
for col in ["Cancer Type", "Donor Sex", "Histology Abbreviation"]:
    df[col] = LabelEncoder().fit_transform(df[col])

# === Encode labels
df = df[df["Cancer Stage"].isin([1, 2, 3, 4])]
df["label"] = df["Cancer Stage"].astype(int) - 1

# === Prepare X, y
X = df[["Cancer Type", "Donor Age at Diagnosis", "Donor Sex", "Histology Abbreviation"]].values.astype(np.float32)
y = df["label"].values.astype(np.int64)

# === Normalize
X = StandardScaler().fit_transform(X)

# === Reshape for Transformer: (B, T=1, D)
X = torch.tensor(X).unsqueeze(1)
y = torch.tensor(y)

# === Split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
val_dataset = torch.utils.data.TensorDataset(X_val, y_val)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE)

# === Weighted CE Loss
from sklearn.utils.class_weight import compute_class_weight
weights = compute_class_weight("balanced", classes=np.unique(y_train.numpy()), y=y_train.numpy())
class_weights = torch.tensor(weights, dtype=torch.float32).to(device)
loss_fn = nn.CrossEntropyLoss(weight=class_weights)

# === Transformer Classifier
class TransformerClassifier(nn.Module):
    def __init__(self, dim, heads=2, ff_dim=64, num_classes=4, dropout=0.1):
        super().__init__()
        encoder_layer = nn.TransformerEncoderLayer(d_model=dim, nhead=heads, dim_feedforward=ff_dim,
                                                   dropout=dropout, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=2)
        self.classifier = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = x.mean(dim=1)
        return self.classifier(x)

model = TransformerClassifier(dim=X.shape[-1], num_classes=NUM_CLASSES).to(device)
optimizer = optim.AdamW(model.parameters(), lr=LR)

# === Training loop
train_losses, val_accuracies = [], []
for epoch in range(1, EPOCHS + 1):
    model.train()
    total_loss = 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        logits = model(xb)
        loss = loss_fn(logits, yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    train_losses.append(total_loss / len(train_loader))

    # Validation
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            preds = model(xb).argmax(dim=1)
            correct += (preds == yb).sum().item()
            total += yb.size(0)
    acc = correct / total
    val_accuracies.append(acc)
    print(f"Epoch {epoch:2d} | Loss: {train_losses[-1]:.4f} | Val Acc: {acc:.4f}")

# === Final Report
print("\n📊 Final Classification Report:")
y_true, y_pred = [], []
model.eval()
with torch.no_grad():
    for xb, yb in val_loader:
        xb = xb.to(device)
        pred = model(xb).argmax(dim=1).cpu()
        y_pred.extend(pred.tolist())
        y_true.extend(yb.tolist())
print(classification_report(y_true, y_pred, target_names=[f"Stage {i}" for i in range(4)]))

# === Plot loss and val acc
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Loss", color="red")
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(val_accuracies, label="Val Acc", color="blue")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.grid(True)

plt.suptitle("Training Loss & Validation Accuracy")
plt.tight_layout()
plt.show()
# Out:
# Epoch  1 | Loss: 1.3299 | Val Acc: 0.2143
# Epoch  2 | Loss: 1.1186 | Val Acc: 0.2938
# Epoch  3 | Loss: 1.0501 | Val Acc: 0.2866
# Epoch  4 | Loss: 1.0167 | Val Acc: 0.3413
# Epoch  5 | Loss: 0.9950 | Val Acc: 0.3755
# Epoch  6 | Loss: 0.9791 | Val Acc: 0.3931
# Epoch  7 | Loss: 0.9662 | Val Acc: 0.4026
# Epoch  8 | Loss: 0.9566 | Val Acc: 0.3972
# Epoch  9 | Loss: 0.9469 | Val Acc: 0.4117
# Epoch 10 | Loss: 0.9354 | Val Acc: 0.4326
# Epoch 11 | Loss: 0.9278 | Val Acc: 0.4315
# Epoch 12 | Loss: 0.9184 | Val Acc: 0.4676
# Epoch 13 | Loss: 0.9083 | Val Acc: 0.4481
# Epoch 14 | Loss: 0.9033 | Val Acc: 0.4676
# Epoch 15 | Loss: 0.8971 | Val Acc: 0.4723
# Epoch 16 | Loss: 0.8885 | Val Acc: 0.4481
# Epoch 17 | Loss: 0.8831 | Val Acc: 0.4750
# Epoch 18 | Loss: 0.8757 | Val Acc: 0.4676
# Epoch 19 | Loss: 0.8671 | Val Acc: 0.4709
# Epoch 20 | Loss: 0.8623 | Val Acc: 0.4718
# Epoch 21 | Loss: 0.8522 | Val Acc: 0.4718
# Epoch 22 | Loss: 0.8498 | Val Acc: 0.4984
# Epoch 23 | Loss: 0.8438 | Val Acc: 0.4941
# Epoch 24 | Loss: 0.8368 | Val Acc: 0.4731
# Epoch 25 | Loss: 0.8305 | Val Acc: 0.4686
# Epoch 26 | Loss: 0.8252 | Val Acc: 0.4686
# Epoch 27 | Loss: 0.8235 | Val Acc: 0.4724
# Epoch 28 | Loss: 0.8172 | Val Acc: 0.4844
# Epoch 29 | Loss: 0.8184 | Val Acc: 0.4794
# Epoch 30 | Loss: 0.8150 | Val Acc: 0.4788
# Epoch 31 | Loss: 0.8123 | Val Acc: 0.4872
# Epoch 32 | Loss: 0.8051 | Val Acc: 0.4895
# Epoch 33 | Loss: 0.8012 | Val Acc: 0.4907
# Epoch 34 | Loss: 0.8027 | Val Acc: 0.4851
# Epoch 35 | Loss: 0.7986 | Val Acc: 0.4855
# Epoch 36 | Loss: 0.7946 | Val Acc: 0.4905
# Epoch 37 | Loss: 0.7883 | Val Acc: 0.4878
# Epoch 38 | Loss: 0.7942 | Val Acc: 0.4787
# Epoch 39 | Loss: 0.7946 | Val Acc: 0.4869
# Epoch 40 | Loss: 0.7861 | Val Acc: 0.4800
# Epoch 41 | Loss: 0.7848 | Val Acc: 0.4809
# Epoch 42 | Loss: 0.7840 | Val Acc: 0.4773
# Epoch 43 | Loss: 0.7786 | Val Acc: 0.4814
# Epoch 44 | Loss: 0.7788 | Val Acc: 0.4814
# Epoch 45 | Loss: 0.7821 | Val Acc: 0.4757
# Epoch 46 | Loss: 0.7799 | Val Acc: 0.4735
# Epoch 47 | Loss: 0.7777 | Val Acc: 0.4814
# Epoch 48 | Loss: 0.7807 | Val Acc: 0.4799
# Epoch 49 | Loss: 0.7712 | Val Acc: 0.4773
# Epoch 50 | Loss: 0.7690 | Val Acc: 0.4701
# Epoch 51 | Loss: 0.7697 | Val Acc: 0.4735
# Epoch 52 | Loss: 0.7703 | Val Acc: 0.4813
# Epoch 53 | Loss: 0.7689 | Val Acc: 0.4833
# Epoch 54 | Loss: 0.7706 | Val Acc: 0.4773
# Epoch 55 | Loss: 0.7700 | Val Acc: 0.4791
# Epoch 56 | Loss: 0.7745 | Val Acc: 0.4763
# Epoch 57 | Loss: 0.7590 | Val Acc: 0.4827
# Epoch 58 | Loss: 0.7657 | Val Acc: 0.4778
# Epoch 59 | Loss: 0.7637 | Val Acc: 0.4800
# Epoch 60 | Loss: 0.7631 | Val Acc: 0.4753
# Epoch 61 | Loss: 0.7645 | Val Acc: 0.4824
# Epoch 62 | Loss: 0.7599 | Val Acc: 0.4833
# Epoch 63 | Loss: 0.7607 | Val Acc: 0.4750
# Epoch 64 | Loss: 0.7600 | Val Acc: 0.4773
# Epoch 65 | Loss: 0.7574 | Val Acc: 0.4833
# Epoch 66 | Loss: 0.7532 | Val Acc: 0.4811
# Epoch 67 | Loss: 0.7545 | Val Acc: 0.4784
# Epoch 68 | Loss: 0.7567 | Val Acc: 0.4720
# Epoch 69 | Loss: 0.7547 | Val Acc: 0.4813
# Epoch 70 | Loss: 0.7503 | Val Acc: 0.5037
# Epoch 71 | Loss: 0.7548 | Val Acc: 0.5016
# Epoch 72 | Loss: 0.7517 | Val Acc: 0.4698
# Epoch 73 | Loss: 0.7498 | Val Acc: 0.4993
# Epoch 74 | Loss: 0.7534 | Val Acc: 0.5007
# Epoch 75 | Loss: 0.7509 | Val Acc: 0.4991
# Epoch 76 | Loss: 0.7517 | Val Acc: 0.4795
# Epoch 77 | Loss: 0.7505 | Val Acc: 0.4941
# Epoch 78 | Loss: 0.7508 | Val Acc: 0.5021
# Epoch 79 | Loss: 0.7483 | Val Acc: 0.5013
# Epoch 80 | Loss: 0.7485 | Val Acc: 0.5000
# Epoch 81 | Loss: 0.7487 | Val Acc: 0.5030
# Epoch 82 | Loss: 0.7506 | Val Acc: 0.5027
# Epoch 83 | Loss: 0.7467 | Val Acc: 0.4935
# Epoch 84 | Loss: 0.7470 | Val Acc: 0.4941
# Epoch 85 | Loss: 0.7484 | Val Acc: 0.5014
# Epoch 86 | Loss: 0.7479 | Val Acc: 0.4999
# Epoch 87 | Loss: 0.7426 | Val Acc: 0.5035
# Epoch 88 | Loss: 0.7430 | Val Acc: 0.4999
# Epoch 89 | Loss: 0.7433 | Val Acc: 0.5000
# Epoch 90 | Loss: 0.7494 | Val Acc: 0.4999
# Epoch 91 | Loss: 0.7445 | Val Acc: 0.5013
# Epoch 92 | Loss: 0.7377 | Val Acc: 0.4999
# Epoch 93 | Loss: 0.7416 | Val Acc: 0.5000
# Epoch 94 | Loss: 0.7458 | Val Acc: 0.5106
# Epoch 95 | Loss: 0.7372 | Val Acc: 0.5035
# Epoch 96 | Loss: 0.7423 | Val Acc: 0.5024
# Epoch 97 | Loss: 0.7395 | Val Acc: 0.5037
# Epoch 98 | Loss: 0.7361 | Val Acc: 0.5000
# Epoch 99 | Loss: 0.7383 | Val Acc: 0.5112
# Epoch 100 | Loss: 0.7358 | Val Acc: 0.5114
# Epoch 101 | Loss: 0.7401 | Val Acc: 0.5064
# Epoch 102 | Loss: 0.7435 | Val Acc: 0.5052
# Epoch 103 | Loss: 0.7364 | Val Acc: 0.5169
# Epoch 104 | Loss: 0.7401 | Val Acc: 0.5141
# Epoch 105 | Loss: 0.7370 | Val Acc: 0.5135
# Epoch 106 | Loss: 0.7406 | Val Acc: 0.5046
# Epoch 107 | Loss: 0.7374 | Val Acc: 0.5169
# Epoch 108 | Loss: 0.7390 | Val Acc: 0.5098
# Epoch 109 | Loss: 0.7347 | Val Acc: 0.5115
# Epoch 110 | Loss: 0.7307 | Val Acc: 0.5059
# Epoch 111 | Loss: 0.7363 | Val Acc: 0.5137
# Epoch 112 | Loss: 0.7313 | Val Acc: 0.5060
# Epoch 113 | Loss: 0.7313 | Val Acc: 0.5150
# Epoch 114 | Loss: 0.7255 | Val Acc: 0.5115
# Epoch 115 | Loss: 0.7309 | Val Acc: 0.5239
# Epoch 116 | Loss: 0.7330 | Val Acc: 0.5149
# Epoch 117 | Loss: 0.7316 | Val Acc: 0.5159
# Epoch 118 | Loss: 0.7290 | Val Acc: 0.5137
# Epoch 119 | Loss: 0.7298 | Val Acc: 0.5153
# Epoch 120 | Loss: 0.7298 | Val Acc: 0.5115
# Epoch 121 | Loss: 0.7300 | Val Acc: 0.5150
# Epoch 122 | Loss: 0.7259 | Val Acc: 0.5108
# Epoch 123 | Loss: 0.7291 | Val Acc: 0.5227
# Epoch 124 | Loss: 0.7247 | Val Acc: 0.5239
# Epoch 125 | Loss: 0.7274 | Val Acc: 0.5175
# Epoch 126 | Loss: 0.7280 | Val Acc: 0.5179
# Epoch 127 | Loss: 0.7235 | Val Acc: 0.5095
# Epoch 128 | Loss: 0.7240 | Val Acc: 0.5191
# Epoch 129 | Loss: 0.7263 | Val Acc: 0.5234
# Epoch 130 | Loss: 0.7245 | Val Acc: 0.5293
# Epoch 131 | Loss: 0.7274 | Val Acc: 0.5239
# Epoch 132 | Loss: 0.7201 | Val Acc: 0.5195
# Epoch 133 | Loss: 0.7172 | Val Acc: 0.5112
# Epoch 134 | Loss: 0.7283 | Val Acc: 0.5184
# Epoch 135 | Loss: 0.7220 | Val Acc: 0.5205
# Epoch 136 | Loss: 0.7200 | Val Acc: 0.5135
# Epoch 137 | Loss: 0.7115 | Val Acc: 0.5260
# Epoch 138 | Loss: 0.7267 | Val Acc: 0.5223
# Epoch 139 | Loss: 0.7222 | Val Acc: 0.5261
# Epoch 140 | Loss: 0.7185 | Val Acc: 0.5233
# Epoch 141 | Loss: 0.7146 | Val Acc: 0.5182
# Epoch 142 | Loss: 0.7206 | Val Acc: 0.5169
# Epoch 143 | Loss: 0.7228 | Val Acc: 0.5235
# Epoch 144 | Loss: 0.7185 | Val Acc: 0.5188
# Epoch 145 | Loss: 0.7208 | Val Acc: 0.5186
# Epoch 146 | Loss: 0.7150 | Val Acc: 0.5239
# Epoch 147 | Loss: 0.7147 | Val Acc: 0.5169
# Epoch 148 | Loss: 0.7128 | Val Acc: 0.5227
# Epoch 149 | Loss: 0.7120 | Val Acc: 0.5153
# Epoch 150 | Loss: 0.7133 | Val Acc: 0.5171
# Epoch 151 | Loss: 0.7152 | Val Acc: 0.5182
# Epoch 152 | Loss: 0.7099 | Val Acc: 0.5189
# Epoch 153 | Loss: 0.7127 | Val Acc: 0.5188
# Epoch 154 | Loss: 0.7188 | Val Acc: 0.5148
# Epoch 155 | Loss: 0.7090 | Val Acc: 0.5191
# Epoch 156 | Loss: 0.7069 | Val Acc: 0.5123
# Epoch 157 | Loss: 0.7100 | Val Acc: 0.5153
# Epoch 158 | Loss: 0.7122 | Val Acc: 0.5135
# Epoch 159 | Loss: 0.7098 | Val Acc: 0.5148
# Epoch 160 | Loss: 0.7067 | Val Acc: 0.5119
# Epoch 161 | Loss: 0.7042 | Val Acc: 0.5153
# Epoch 162 | Loss: 0.7030 | Val Acc: 0.5261
# Epoch 163 | Loss: 0.7053 | Val Acc: 0.5220
# Epoch 164 | Loss: 0.7025 | Val Acc: 0.5265
# Epoch 165 | Loss: 0.7080 | Val Acc: 0.5150
# Epoch 166 | Loss: 0.7069 | Val Acc: 0.5176
# Epoch 167 | Loss: 0.7097 | Val Acc: 0.5197
# Epoch 168 | Loss: 0.7058 | Val Acc: 0.5119
# Epoch 169 | Loss: 0.7020 | Val Acc: 0.5161
# Epoch 170 | Loss: 0.7072 | Val Acc: 0.5227
# Epoch 171 | Loss: 0.7069 | Val Acc: 0.5157
# Epoch 172 | Loss: 0.7018 | Val Acc: 0.5184
# Epoch 173 | Loss: 0.7029 | Val Acc: 0.5186
# Epoch 174 | Loss: 0.7047 | Val Acc: 0.5148
# Epoch 175 | Loss: 0.7009 | Val Acc: 0.5213
# Epoch 176 | Loss: 0.6965 | Val Acc: 0.5161
# Epoch 177 | Loss: 0.7044 | Val Acc: 0.5148
# Epoch 178 | Loss: 0.7046 | Val Acc: 0.5218
# Epoch 179 | Loss: 0.7037 | Val Acc: 0.5237
# Epoch 180 | Loss: 0.7012 | Val Acc: 0.5148
# Epoch 181 | Loss: 0.6995 | Val Acc: 0.5205
# Epoch 182 | Loss: 0.6963 | Val Acc: 0.5119
# Epoch 183 | Loss: 0.7024 | Val Acc: 0.5221
# Epoch 184 | Loss: 0.6936 | Val Acc: 0.5161
# Epoch 185 | Loss: 0.6990 | Val Acc: 0.5148
# Epoch 186 | Loss: 0.6997 | Val Acc: 0.5161
# Epoch 187 | Loss: 0.6956 | Val Acc: 0.5157
# Epoch 188 | Loss: 0.7002 | Val Acc: 0.5259
# Epoch 189 | Loss: 0.6949 | Val Acc: 0.5148
# Epoch 190 | Loss: 0.6994 | Val Acc: 0.5119
# Epoch 191 | Loss: 0.6988 | Val Acc: 0.5189
# Epoch 192 | Loss: 0.6931 | Val Acc: 0.5148
# Epoch 193 | Loss: 0.6958 | Val Acc: 0.5148
# Epoch 194 | Loss: 0.6992 | Val Acc: 0.5157
# Epoch 195 | Loss: 0.6940 | Val Acc: 0.5227
# Epoch 196 | Loss: 0.6997 | Val Acc: 0.5189
# Epoch 197 | Loss: 0.6946 | Val Acc: 0.5119
# Epoch 198 | Loss: 0.6955 | Val Acc: 0.5221
# Epoch 199 | Loss: 0.6980 | Val Acc: 0.5163
# Epoch 200 | Loss: 0.6970 | Val Acc: 0.5148
# Epoch 201 | Loss: 0.6993 | Val Acc: 0.5189
# Epoch 202 | Loss: 0.6950 | Val Acc: 0.5227
# Epoch 203 | Loss: 0.6927 | Val Acc: 0.5189
# Epoch 204 | Loss: 0.6962 | Val Acc: 0.5148
# Epoch 205 | Loss: 0.6906 | Val Acc: 0.5157
# Epoch 206 | Loss: 0.6915 | Val Acc: 0.5148
# Epoch 207 | Loss: 0.6916 | Val Acc: 0.5148
# Epoch 208 | Loss: 0.6851 | Val Acc: 0.5217
# Epoch 209 | Loss: 0.6914 | Val Acc: 0.5189
# Epoch 210 | Loss: 0.6962 | Val Acc: 0.5163
# Epoch 211 | Loss: 0.6901 | Val Acc: 0.5119
# Epoch 212 | Loss: 0.6937 | Val Acc: 0.5163
# Epoch 213 | Loss: 0.6852 | Val Acc: 0.5176
# Epoch 214 | Loss: 0.6941 | Val Acc: 0.5186
# Epoch 215 | Loss: 0.6849 | Val Acc: 0.5212
# Epoch 216 | Loss: 0.6934 | Val Acc: 0.5115
# Epoch 217 | Loss: 0.6953 | Val Acc: 0.5282
# Epoch 218 | Loss: 0.6881 | Val Acc: 0.5180
# Epoch 219 | Loss: 0.6883 | Val Acc: 0.5148
# Epoch 220 | Loss: 0.6898 | Val Acc: 0.5186
# Epoch 221 | Loss: 0.6914 | Val Acc: 0.5148
# Epoch 222 | Loss: 0.6907 | Val Acc: 0.5213
# Epoch 223 | Loss: 0.6836 | Val Acc: 0.5186
# Epoch 224 | Loss: 0.6855 | Val Acc: 0.5250
# Epoch 225 | Loss: 0.6811 | Val Acc: 0.5229
# Epoch 226 | Loss: 0.6900 | Val Acc: 0.5196
# Epoch 227 | Loss: 0.6827 | Val Acc: 0.5153
# Epoch 228 | Loss: 0.6842 | Val Acc: 0.5218
# Epoch 229 | Loss: 0.6875 | Val Acc: 0.5195
# Epoch 230 | Loss: 0.6806 | Val Acc: 0.5205
# Epoch 231 | Loss: 0.6816 | Val Acc: 0.5227
# Epoch 232 | Loss: 0.6852 | Val Acc: 0.5227
# Epoch 233 | Loss: 0.6896 | Val Acc: 0.5256
# Epoch 234 | Loss: 0.6802 | Val Acc: 0.5251
# Epoch 235 | Loss: 0.6909 | Val Acc: 0.5124
# Epoch 236 | Loss: 0.6872 | Val Acc: 0.5153
# Epoch 237 | Loss: 0.6851 | Val Acc: 0.5153
# Epoch 238 | Loss: 0.6845 | Val Acc: 0.5118
# Epoch 239 | Loss: 0.6896 | Val Acc: 0.5153
# Epoch 240 | Loss: 0.6856 | Val Acc: 0.5176
# Epoch 241 | Loss: 0.6819 | Val Acc: 0.5180
# Epoch 242 | Loss: 0.6766 | Val Acc: 0.5255
# Epoch 243 | Loss: 0.6833 | Val Acc: 0.5255
# Epoch 244 | Loss: 0.6801 | Val Acc: 0.5218
# Epoch 245 | Loss: 0.6847 | Val Acc: 0.5176
# Epoch 246 | Loss: 0.6794 | Val Acc: 0.5180
# Epoch 247 | Loss: 0.6819 | Val Acc: 0.5176
# Epoch 248 | Loss: 0.6776 | Val Acc: 0.5286
# Epoch 249 | Loss: 0.6802 | Val Acc: 0.5218
# Epoch 250 | Loss: 0.6823 | Val Acc: 0.5131
# Epoch 251 | Loss: 0.6805 | Val Acc: 0.5131
# Epoch 252 | Loss: 0.6893 | Val Acc: 0.5218
# Epoch 253 | Loss: 0.6811 | Val Acc: 0.5244
# Epoch 254 | Loss: 0.6742 | Val Acc: 0.5196
# Epoch 255 | Loss: 0.6738 | Val Acc: 0.5218
# Epoch 256 | Loss: 0.6847 | Val Acc: 0.5191
# Epoch 257 | Loss: 0.6782 | Val Acc: 0.5218
# Epoch 258 | Loss: 0.6758 | Val Acc: 0.5180
# Epoch 259 | Loss: 0.6722 | Val Acc: 0.5192
# Epoch 260 | Loss: 0.6833 | Val Acc: 0.5180
# Epoch 261 | Loss: 0.6789 | Val Acc: 0.5282
# Epoch 262 | Loss: 0.6817 | Val Acc: 0.5115
# Epoch 263 | Loss: 0.6760 | Val Acc: 0.5250
# Epoch 264 | Loss: 0.6806 | Val Acc: 0.5196
# Epoch 265 | Loss: 0.6800 | Val Acc: 0.5256
# Epoch 266 | Loss: 0.6803 | Val Acc: 0.5196
# Epoch 267 | Loss: 0.6821 | Val Acc: 0.5218
# Epoch 268 | Loss: 0.6753 | Val Acc: 0.5180
# Epoch 269 | Loss: 0.6758 | Val Acc: 0.5186
# Epoch 270 | Loss: 0.6739 | Val Acc: 0.5180
# Epoch 271 | Loss: 0.6771 | Val Acc: 0.5115
# Epoch 272 | Loss: 0.6764 | Val Acc: 0.5180
# Epoch 273 | Loss: 0.6683 | Val Acc: 0.5218
# Epoch 274 | Loss: 0.6715 | Val Acc: 0.5180
# Epoch 275 | Loss: 0.6758 | Val Acc: 0.5180
# Epoch 276 | Loss: 0.6714 | Val Acc: 0.5255
# Epoch 277 | Loss: 0.6718 | Val Acc: 0.5196
# Epoch 278 | Loss: 0.6795 | Val Acc: 0.5192
# Epoch 279 | Loss: 0.6735 | Val Acc: 0.5218
# Epoch 280 | Loss: 0.6758 | Val Acc: 0.5180
# Epoch 281 | Loss: 0.6717 | Val Acc: 0.5218
# Epoch 282 | Loss: 0.6741 | Val Acc: 0.5153
# Epoch 283 | Loss: 0.6692 | Val Acc: 0.5180
# Epoch 284 | Loss: 0.6728 | Val Acc: 0.5218
# Epoch 285 | Loss: 0.6725 | Val Acc: 0.5180
# Epoch 286 | Loss: 0.6686 | Val Acc: 0.5214
# Epoch 287 | Loss: 0.6681 | Val Acc: 0.5293
# Epoch 288 | Loss: 0.6732 | Val Acc: 0.5559
# Epoch 289 | Loss: 0.6709 | Val Acc: 0.5176
# Epoch 290 | Loss: 0.6727 | Val Acc: 0.5214
# Epoch 291 | Loss: 0.6658 | Val Acc: 0.5218
# Epoch 292 | Loss: 0.6703 | Val Acc: 0.5218
# Epoch 293 | Loss: 0.6676 | Val Acc: 0.5180
# Epoch 294 | Loss: 0.6743 | Val Acc: 0.5180
# Epoch 295 | Loss: 0.6687 | Val Acc: 0.5212
# Epoch 296 | Loss: 0.6681 | Val Acc: 0.5218
# Epoch 297 | Loss: 0.6694 | Val Acc: 0.5218
# Epoch 298 | Loss: 0.6678 | Val Acc: 0.5180
# Epoch 299 | Loss: 0.6667 | Val Acc: 0.5246
# Epoch 300 | Loss: 0.6729 | Val Acc: 0.5141
#
# 📊 Final Classification Report:
#               precision    recall  f1-score   support
#
#      Stage 0       0.37      0.95      0.54       642
#      Stage 1       0.58      0.82      0.68      1436
#      Stage 2       0.98      0.34      0.50      5115
#      Stage 3       0.19      0.93      0.32       459
#
#     accuracy                           0.51      7652
#    macro avg       0.53      0.76      0.51      7652
# weighted avg       0.81      0.51      0.53      7652

# %% [markdown]
# ## Fusion (Prot+Clinical)

# %%
# === Imports ===
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader, Subset

# === Config ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
EMBED_DIM = 320
NUM_CLASSES = 4
BATCH_SIZE = 64
LR = 1e-4
EPOCHS = 300

# === Load .pt Embedding Data ===
embedding_data = torch.load("data/esm2_embeddings.pt")
delta_X = embedding_data['X']  # shape: [N, 1280]
labels = embedding_data['y']

# === Load Clinical CSV ===
clinical_df = pd.read_csv("data/cancer_data_preprocessed.csv")
clinical_df = clinical_df[["Cancer Type", "Donor Age at Diagnosis", "Donor Sex", "Histology Abbreviation", "Cancer Stage"]].dropna()
clinical_df = clinical_df[clinical_df["Cancer Stage"].isin([1, 2, 3, 4])].reset_index(drop=True)

# === Encode Clinical Features ===
for col in ["Cancer Type", "Donor Sex", "Histology Abbreviation"]:
    clinical_df[col] = LabelEncoder().fit_transform(clinical_df[col])
clinical_df["label"] = clinical_df["Cancer Stage"].astype(int) - 1

# === Dataset Class ===
class CombinedEmbeddingDataset(Dataset):
    def __init__(self, clinical_df, delta_embed_tensor):
        self.age = torch.tensor(clinical_df["Donor Age at Diagnosis"].values, dtype=torch.float32).unsqueeze(-1)
        self.sex = torch.tensor(clinical_df["Donor Sex"].values, dtype=torch.long)
        self.cancer = torch.tensor(clinical_df["Cancer Type"].values, dtype=torch.long)
        self.hist = torch.tensor(clinical_df["Histology Abbreviation"].values, dtype=torch.long)
        self.labels = torch.tensor(clinical_df["label"].values, dtype=torch.long)
        self.delta_embed = delta_embed_tensor.float()

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return (
            self.age[idx], self.sex[idx], self.cancer[idx], self.hist[idx],
            self.delta_embed[idx], self.labels[idx]
        )

# === Clinical Embedding ===
class ClinicalEmbedding(nn.Module):
    def __init__(self, embed_dim):
        super().__init__()
        self.age_proj = nn.Linear(1, embed_dim)
        self.sex_embed = nn.Embedding(2, embed_dim)
        self.cancer_embed = nn.Embedding(20, embed_dim)
        self.hist_embed = nn.Embedding(30, embed_dim)

    def forward(self, age, sex, cancer, hist):
        age_emb = self.age_proj(age)
        sex_emb = self.sex_embed(sex)
        cancer_emb = self.cancer_embed(cancer)
        hist_emb = self.hist_embed(hist)
        return torch.stack([age_emb, sex_emb, cancer_emb, hist_emb], dim=1)  # [B, 4, D]

def split_delta_embedding(delta_embed, n_tokens=4):
    return delta_embed.view(delta_embed.size(0), n_tokens, -1)  # [B, 4, 320]

# === Transformer Model ===
class TransformerClassifier(nn.Module):
    def __init__(self, dim, heads=2, ff_dim=64, num_classes=4, dropout=0.1):
        super().__init__()
        encoder_layer = nn.TransformerEncoderLayer(d_model=dim, nhead=heads, dim_feedforward=ff_dim,
                                                   dropout=dropout, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=2)
        self.classifier = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = x.mean(dim=1)
        return self.classifier(x)

# === Data Preparation ===
dataset = CombinedEmbeddingDataset(clinical_df, delta_X)
train_idx, val_idx = train_test_split(range(len(dataset)), test_size=0.2, stratify=dataset.labels.numpy())
train_loader = DataLoader(Subset(dataset, train_idx), batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(Subset(dataset, val_idx), batch_size=BATCH_SIZE)

# === Model Init ===
clinical_embedder = ClinicalEmbedding(EMBED_DIM).to(device)
model = TransformerClassifier(dim=EMBED_DIM, num_classes=NUM_CLASSES).to(device)
optimizer = optim.AdamW(list(model.parameters()) + list(clinical_embedder.parameters()), lr=LR)
loss_fn = nn.CrossEntropyLoss()

# === Training Loop ===
train_losses, val_accuracies = [], []
for epoch in range(1, EPOCHS + 1):
    model.train()
    clinical_embedder.train()
    total_loss = 0
    for age, sex, cancer, hist, delta, label in train_loader:
        age, sex, cancer, hist = age.to(device), sex.to(device), cancer.to(device), hist.to(device)
        delta, label = delta.to(device), label.to(device)

        clinical_token = clinical_embedder(age, sex, cancer, hist)
        delta_token = split_delta_embedding(delta)
        x = torch.cat([clinical_token, delta_token], dim=1)  # [B, 8, 320]

        output = model(x)
        loss = loss_fn(output, label)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    train_losses.append(total_loss / len(train_loader))

    # === Validation ===
    model.eval()
    clinical_embedder.eval()
    correct, total = 0, 0
    y_true, y_pred = [], []
    with torch.no_grad():
        for age, sex, cancer, hist, delta, label in val_loader:
            age, sex, cancer, hist = age.to(device), sex.to(device), cancer.to(device), hist.to(device)
            delta, label = delta.to(device), label.to(device)
            clinical_token = clinical_embedder(age, sex, cancer, hist)
            delta_token = split_delta_embedding(delta)
            x = torch.cat([clinical_token, delta_token], dim=1)
            preds = model(x).argmax(dim=1)
            correct += (preds == label).sum().item()
            total += label.size(0)
            y_true.extend(label.cpu().tolist())
            y_pred.extend(preds.cpu().tolist())
    acc = correct / total
    val_accuracies.append(acc)
    print(f"Epoch {epoch:2d} | Loss: {train_losses[-1]:.4f} | Val Acc: {acc:.4f}")

# === Plot Results ===
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.title("Training Loss")

plt.subplot(1, 2, 2)
plt.plot(val_accuracies, label="Val Acc", color="orange")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.title("Validation Accuracy")
plt.tight_layout()
plt.show()

# === Final Classification Report ===
print("\n📊 Final Classification Report:")
print(classification_report(y_true, y_pred, target_names=[f"Stage {i}" for i in range(NUM_CLASSES)]))
# Out:
# Epoch  1 | Loss: 0.6990 | Val Acc: 0.7112
# Epoch  2 | Loss: 0.6654 | Val Acc: 0.7118
# Epoch  3 | Loss: 0.6624 | Val Acc: 0.7172
# Epoch  4 | Loss: 0.6578 | Val Acc: 0.7135
# Epoch  5 | Loss: 0.6555 | Val Acc: 0.7165
# Epoch  6 | Loss: 0.6522 | Val Acc: 0.7193
# Epoch  7 | Loss: 0.6492 | Val Acc: 0.7186
# Epoch  8 | Loss: 0.6479 | Val Acc: 0.7312
# Epoch  9 | Loss: 0.6460 | Val Acc: 0.7229
# Epoch 10 | Loss: 0.6502 | Val Acc: 0.7243
# Epoch 11 | Loss: 0.6426 | Val Acc: 0.7236
# Epoch 12 | Loss: 0.6401 | Val Acc: 0.7211
# Epoch 13 | Loss: 0.6387 | Val Acc: 0.7313
# Epoch 14 | Loss: 0.6354 | Val Acc: 0.7333
# Epoch 15 | Loss: 0.6316 | Val Acc: 0.7321
# Epoch 16 | Loss: 0.6300 | Val Acc: 0.7290
# Epoch 17 | Loss: 0.6253 | Val Acc: 0.7266
# Epoch 18 | Loss: 0.6232 | Val Acc: 0.7325
# Epoch 19 | Loss: 0.6178 | Val Acc: 0.7314
# Epoch 20 | Loss: 0.6164 | Val Acc: 0.7350
# Epoch 21 | Loss: 0.6111 | Val Acc: 0.7401
# Epoch 22 | Loss: 0.6049 | Val Acc: 0.7390
# Epoch 23 | Loss: 0.6012 | Val Acc: 0.7415
# Epoch 24 | Loss: 0.5938 | Val Acc: 0.7533
# Epoch 25 | Loss: 0.5883 | Val Acc: 0.7256
# Epoch 26 | Loss: 0.5790 | Val Acc: 0.7509
# Epoch 27 | Loss: 0.5724 | Val Acc: 0.7565
# Epoch 28 | Loss: 0.5669 | Val Acc: 0.7561
# Epoch 29 | Loss: 0.5568 | Val Acc: 0.7459
# Epoch 30 | Loss: 0.5490 | Val Acc: 0.7627
# Epoch 31 | Loss: 0.5382 | Val Acc: 0.7635
# Epoch 32 | Loss: 0.5309 | Val Acc: 0.7689
# Epoch 33 | Loss: 0.5264 | Val Acc: 0.7723
# Epoch 34 | Loss: 0.5172 | Val Acc: 0.7691
# Epoch 35 | Loss: 0.5041 | Val Acc: 0.7774
# Epoch 36 | Loss: 0.4973 | Val Acc: 0.7765
# Epoch 37 | Loss: 0.4888 | Val Acc: 0.7748
# Epoch 38 | Loss: 0.4899 | Val Acc: 0.7849
# Epoch 39 | Loss: 0.4764 | Val Acc: 0.7841
# Epoch 40 | Loss: 0.4668 | Val Acc: 0.7836
# Epoch 41 | Loss: 0.4623 | Val Acc: 0.7824
# Epoch 42 | Loss: 0.4498 | Val Acc: 0.7936
# Epoch 43 | Loss: 0.4339 | Val Acc: 0.7919
# Epoch 44 | Loss: 0.4302 | Val Acc: 0.8061
# Epoch 45 | Loss: 0.4157 | Val Acc: 0.8093
# Epoch 46 | Loss: 0.4153 | Val Acc: 0.8021
# Epoch 47 | Loss: 0.3992 | Val Acc: 0.8053
# Epoch 48 | Loss: 0.3979 | Val Acc: 0.8104
# Epoch 49 | Loss: 0.3909 | Val Acc: 0.8125
# Epoch 50 | Loss: 0.3753 | Val Acc: 0.8177
# Epoch 51 | Loss: 0.3675 | Val Acc: 0.8200
# Epoch 52 | Loss: 0.3592 | Val Acc: 0.8244
# Epoch 53 | Loss: 0.3563 | Val Acc: 0.8136
# Epoch 54 | Loss: 0.3444 | Val Acc: 0.8225
# Epoch 55 | Loss: 0.3387 | Val Acc: 0.8284
# Epoch 56 | Loss: 0.3318 | Val Acc: 0.8246
# Epoch 57 | Loss: 0.3289 | Val Acc: 0.8262
# Epoch 58 | Loss: 0.3200 | Val Acc: 0.8206
# Epoch 59 | Loss: 0.3133 | Val Acc: 0.8325
# Epoch 60 | Loss: 0.3105 | Val Acc: 0.8339
# Epoch 61 | Loss: 0.3035 | Val Acc: 0.8348
# Epoch 62 | Loss: 0.2930 | Val Acc: 0.8326
# Epoch 63 | Loss: 0.2883 | Val Acc: 0.8369
# Epoch 64 | Loss: 0.2861 | Val Acc: 0.8408
# Epoch 65 | Loss: 0.2814 | Val Acc: 0.8372
# Epoch 66 | Loss: 0.2752 | Val Acc: 0.8436
# Epoch 67 | Loss: 0.2741 | Val Acc: 0.8437
# Epoch 68 | Loss: 0.2669 | Val Acc: 0.8442
# Epoch 69 | Loss: 0.2616 | Val Acc: 0.8472
# Epoch 70 | Loss: 0.2572 | Val Acc: 0.8508
# Epoch 71 | Loss: 0.2531 | Val Acc: 0.8466
# Epoch 72 | Loss: 0.2490 | Val Acc: 0.8430
# Epoch 73 | Loss: 0.2431 | Val Acc: 0.8472
# Epoch 74 | Loss: 0.2404 | Val Acc: 0.8539
# Epoch 75 | Loss: 0.2344 | Val Acc: 0.8568
# Epoch 76 | Loss: 0.2308 | Val Acc: 0.8445
# Epoch 77 | Loss: 0.2284 | Val Acc: 0.8530
# Epoch 78 | Loss: 0.2287 | Val Acc: 0.8437
# Epoch 79 | Loss: 0.2284 | Val Acc: 0.8572
# Epoch 80 | Loss: 0.2180 | Val Acc: 0.8559
# Epoch 81 | Loss: 0.2196 | Val Acc: 0.8527
# Epoch 82 | Loss: 0.2233 | Val Acc: 0.8487
# Epoch 83 | Loss: 0.2092 | Val Acc: 0.8604
# Epoch 84 | Loss: 0.2095 | Val Acc: 0.8569
# Epoch 85 | Loss: 0.2043 | Val Acc: 0.8623
# Epoch 86 | Loss: 0.2027 | Val Acc: 0.8547
# Epoch 87 | Loss: 0.2057 | Val Acc: 0.8528
# Epoch 88 | Loss: 0.1968 | Val Acc: 0.8535
# Epoch 89 | Loss: 0.1959 | Val Acc: 0.8534
# Epoch 90 | Loss: 0.1932 | Val Acc: 0.8576
# Epoch 91 | Loss: 0.1915 | Val Acc: 0.8545
# Epoch 92 | Loss: 0.1829 | Val Acc: 0.8619
# Epoch 93 | Loss: 0.1873 | Val Acc: 0.8634
# Epoch 94 | Loss: 0.2018 | Val Acc: 0.8570
# Epoch 95 | Loss: 0.1873 | Val Acc: 0.8551
# Epoch 96 | Loss: 0.1885 | Val Acc: 0.8672
# Epoch 97 | Loss: 0.1871 | Val Acc: 0.8621
# Epoch 98 | Loss: 0.1842 | Val Acc: 0.8650
# Epoch 99 | Loss: 0.1776 | Val Acc: 0.8650
# Epoch 100 | Loss: 0.1816 | Val Acc: 0.8650
# Epoch 101 | Loss: 0.1781 | Val Acc: 0.8684
# Epoch 102 | Loss: 0.1745 | Val Acc: 0.8685
# Epoch 103 | Loss: 0.1731 | Val Acc: 0.8627
# Epoch 104 | Loss: 0.1751 | Val Acc: 0.8638
# Epoch 105 | Loss: 0.1694 | Val Acc: 0.8632
# Epoch 106 | Loss: 0.1638 | Val Acc: 0.8654
# Epoch 107 | Loss: 0.1654 | Val Acc: 0.8709
# Epoch 108 | Loss: 0.1619 | Val Acc: 0.8684
# Epoch 109 | Loss: 0.1673 | Val Acc: 0.8625
# Epoch 110 | Loss: 0.1624 | Val Acc: 0.8670
# Epoch 111 | Loss: 0.1544 | Val Acc: 0.8687
# Epoch 112 | Loss: 0.1578 | Val Acc: 0.8634
# Epoch 113 | Loss: 0.1566 | Val Acc: 0.8636
# Epoch 114 | Loss: 0.1562 | Val Acc: 0.8704
# Epoch 115 | Loss: 0.1553 | Val Acc: 0.8671
# Epoch 116 | Loss: 0.1544 | Val Acc: 0.8642
# Epoch 117 | Loss: 0.1523 | Val Acc: 0.8655
# Epoch 118 | Loss: 0.1528 | Val Acc: 0.8654
# Epoch 119 | Loss: 0.1506 | Val Acc: 0.8700
# Epoch 120 | Loss: 0.1492 | Val Acc: 0.8667
# Epoch 121 | Loss: 0.1471 | Val Acc: 0.8713
# Epoch 122 | Loss: 0.1499 | Val Acc: 0.8685
# Epoch 123 | Loss: 0.1434 | Val Acc: 0.8709
# Epoch 124 | Loss: 0.1609 | Val Acc: 0.8623
# Epoch 125 | Loss: 0.1541 | Val Acc: 0.8709
# Epoch 126 | Loss: 0.1412 | Val Acc: 0.8731
# Epoch 127 | Loss: 0.1386 | Val Acc: 0.8702
# Epoch 128 | Loss: 0.1482 | Val Acc: 0.8677
# Epoch 129 | Loss: 0.1395 | Val Acc: 0.8702
# Epoch 130 | Loss: 0.1387 | Val Acc: 0.8747
# Epoch 131 | Loss: 0.1387 | Val Acc: 0.8633
# Epoch 132 | Loss: 0.1358 | Val Acc: 0.8680
# Epoch 133 | Loss: 0.1426 | Val Acc: 0.8620
# Epoch 134 | Loss: 0.1349 | Val Acc: 0.8704
# Epoch 135 | Loss: 0.1309 | Val Acc: 0.8683
# Epoch 136 | Loss: 0.1320 | Val Acc: 0.8701
# Epoch 137 | Loss: 0.1297 | Val Acc: 0.8680
# Epoch 138 | Loss: 0.1357 | Val Acc: 0.8704
# Epoch 139 | Loss: 0.1267 | Val Acc: 0.8684
# Epoch 140 | Loss: 0.1262 | Val Acc: 0.8710
# Epoch 141 | Loss: 0.1325 | Val Acc: 0.8717
# Epoch 142 | Loss: 0.1237 | Val Acc: 0.8723
# Epoch 143 | Loss: 0.1281 | Val Acc: 0.8723
# Epoch 144 | Loss: 0.1339 | Val Acc: 0.8640
# Epoch 145 | Loss: 0.1347 | Val Acc: 0.8663
# Epoch 146 | Loss: 0.1308 | Val Acc: 0.8709
# Epoch 147 | Loss: 0.1213 | Val Acc: 0.8646
# Epoch 148 | Loss: 0.1253 | Val Acc: 0.8694
# Epoch 149 | Loss: 0.1221 | Val Acc: 0.8668
# Epoch 150 | Loss: 0.1226 | Val Acc: 0.8627
# Epoch 151 | Loss: 0.1271 | Val Acc: 0.8681
# Epoch 152 | Loss: 0.1301 | Val Acc: 0.8628
# Epoch 153 | Loss: 0.1262 | Val Acc: 0.8705
# Epoch 154 | Loss: 0.1288 | Val Acc: 0.8671
# Epoch 155 | Loss: 0.1217 | Val Acc: 0.8702
# Epoch 156 | Loss: 0.1231 | Val Acc: 0.8668
# Epoch 157 | Loss: 0.1160 | Val Acc: 0.8630
# Epoch 158 | Loss: 0.1190 | Val Acc: 0.8757
# Epoch 159 | Loss: 0.1178 | Val Acc: 0.8743
# Epoch 160 | Loss: 0.1179 | Val Acc: 0.8705
# Epoch 161 | Loss: 0.1157 | Val Acc: 0.8739
# Epoch 162 | Loss: 0.1192 | Val Acc: 0.8725
# Epoch 163 | Loss: 0.1164 | Val Acc: 0.8698
# Epoch 164 | Loss: 0.1163 | Val Acc: 0.8696
# Epoch 165 | Loss: 0.1087 | Val Acc: 0.8728
# Epoch 166 | Loss: 0.1167 | Val Acc: 0.8658
# Epoch 167 | Loss: 0.1174 | Val Acc: 0.8693
# Epoch 168 | Loss: 0.1215 | Val Acc: 0.8672
# Epoch 169 | Loss: 0.1184 | Val Acc: 0.8683
# Epoch 170 | Loss: 0.1122 | Val Acc: 0.8723
# Epoch 171 | Loss: 0.1118 | Val Acc: 0.8734
# Epoch 172 | Loss: 0.1098 | Val Acc: 0.8762
# Epoch 173 | Loss: 0.1145 | Val Acc: 0.8745
# Epoch 174 | Loss: 0.1137 | Val Acc: 0.8745
# Epoch 175 | Loss: 0.1083 | Val Acc: 0.8739
# Epoch 176 | Loss: 0.1131 | Val Acc: 0.8742
# Epoch 177 | Loss: 0.1181 | Val Acc: 0.8646
# Epoch 178 | Loss: 0.1222 | Val Acc: 0.8672
# Epoch 179 | Loss: 0.1154 | Val Acc: 0.8713
# Epoch 180 | Loss: 0.1130 | Val Acc: 0.8681
# Epoch 181 | Loss: 0.1078 | Val Acc: 0.8765
# Epoch 182 | Loss: 0.1076 | Val Acc: 0.8702
# Epoch 183 | Loss: 0.1089 | Val Acc: 0.8751
# Epoch 184 | Loss: 0.1103 | Val Acc: 0.8688
# Epoch 185 | Loss: 0.1077 | Val Acc: 0.8748
# Epoch 186 | Loss: 0.1078 | Val Acc: 0.8723
# Epoch 187 | Loss: 0.1073 | Val Acc: 0.8645
# Epoch 188 | Loss: 0.1083 | Val Acc: 0.8694
# Epoch 189 | Loss: 0.1032 | Val Acc: 0.8762
# Epoch 190 | Loss: 0.1086 | Val Acc: 0.8687
# Epoch 191 | Loss: 0.1043 | Val Acc: 0.8676
# Epoch 192 | Loss: 0.1046 | Val Acc: 0.8719
# Epoch 193 | Loss: 0.1068 | Val Acc: 0.8702
# Epoch 194 | Loss: 0.1034 | Val Acc: 0.8744
# Epoch 195 | Loss: 0.1031 | Val Acc: 0.8751
# Epoch 196 | Loss: 0.1044 | Val Acc: 0.8764
# Epoch 197 | Loss: 0.1000 | Val Acc: 0.8748
# Epoch 198 | Loss: 0.1023 | Val Acc: 0.8755
# Epoch 199 | Loss: 0.1044 | Val Acc: 0.8752
# Epoch 200 | Loss: 0.1139 | Val Acc: 0.8734
# Epoch 201 | Loss: 0.1019 | Val Acc: 0.8727
# Epoch 202 | Loss: 0.0989 | Val Acc: 0.8760
# Epoch 203 | Loss: 0.1062 | Val Acc: 0.8687
# Epoch 204 | Loss: 0.1005 | Val Acc: 0.8751
# Epoch 205 | Loss: 0.1034 | Val Acc: 0.8692
# Epoch 206 | Loss: 0.1013 | Val Acc: 0.8706
# Epoch 207 | Loss: 0.0998 | Val Acc: 0.8756
# Epoch 208 | Loss: 0.0980 | Val Acc: 0.8787
# Epoch 209 | Loss: 0.1020 | Val Acc: 0.8696
# Epoch 210 | Loss: 0.1020 | Val Acc: 0.8742
# Epoch 211 | Loss: 0.0981 | Val Acc: 0.8808
# Epoch 212 | Loss: 0.0981 | Val Acc: 0.8714
# Epoch 213 | Loss: 0.0974 | Val Acc: 0.8804
# Epoch 214 | Loss: 0.1016 | Val Acc: 0.8713
# Epoch 215 | Loss: 0.1135 | Val Acc: 0.8677
# Epoch 216 | Loss: 0.1098 | Val Acc: 0.8651
# Epoch 217 | Loss: 0.1071 | Val Acc: 0.8705
# Epoch 218 | Loss: 0.1075 | Val Acc: 0.8688
# Epoch 219 | Loss: 0.1053 | Val Acc: 0.8696
# Epoch 220 | Loss: 0.1044 | Val Acc: 0.8696
# Epoch 221 | Loss: 0.1061 | Val Acc: 0.8709
# Epoch 222 | Loss: 0.1069 | Val Acc: 0.8667
# Epoch 223 | Loss: 0.1043 | Val Acc: 0.8668
# Epoch 224 | Loss: 0.1059 | Val Acc: 0.8675
# Epoch 225 | Loss: 0.1032 | Val Acc: 0.8685
# Epoch 226 | Loss: 0.1060 | Val Acc: 0.8636
# Epoch 227 | Loss: 0.1021 | Val Acc: 0.8668
# Epoch 228 | Loss: 0.1045 | Val Acc: 0.8687
# Epoch 229 | Loss: 0.1067 | Val Acc: 0.8638
# Epoch 230 | Loss: 0.1032 | Val Acc: 0.8654
# Epoch 231 | Loss: 0.1029 | Val Acc: 0.8664
# Epoch 232 | Loss: 0.1064 | Val Acc: 0.8666
# Epoch 233 | Loss: 0.1046 | Val Acc: 0.8697
# Epoch 234 | Loss: 0.1014 | Val Acc: 0.8701
# Epoch 235 | Loss: 0.1034 | Val Acc: 0.8680
# Epoch 236 | Loss: 0.1010 | Val Acc: 0.8664
# Epoch 237 | Loss: 0.1004 | Val Acc: 0.8676
# Epoch 238 | Loss: 0.1014 | Val Acc: 0.8691
# Epoch 239 | Loss: 0.0998 | Val Acc: 0.8710
# Epoch 240 | Loss: 0.1042 | Val Acc: 0.8723
# Epoch 241 | Loss: 0.1024 | Val Acc: 0.8711
# Epoch 242 | Loss: 0.0982 | Val Acc: 0.8676
# Epoch 243 | Loss: 0.0995 | Val Acc: 0.8688
# Epoch 244 | Loss: 0.0996 | Val Acc: 0.8691
# Epoch 245 | Loss: 0.1002 | Val Acc: 0.8693
# Epoch 246 | Loss: 0.0979 | Val Acc: 0.8698
# Epoch 247 | Loss: 0.1049 | Val Acc: 0.8689
# Epoch 248 | Loss: 0.1006 | Val Acc: 0.8683
# Epoch 249 | Loss: 0.1008 | Val Acc: 0.8675
# Epoch 250 | Loss: 0.0967 | Val Acc: 0.8692
# Epoch 251 | Loss: 0.0990 | Val Acc: 0.8680
# Epoch 252 | Loss: 0.0981 | Val Acc: 0.8687
# Epoch 253 | Loss: 0.0972 | Val Acc: 0.8640
# Epoch 254 | Loss: 0.1017 | Val Acc: 0.8688
# Epoch 255 | Loss: 0.0985 | Val Acc: 0.8679
# Epoch 256 | Loss: 0.1013 | Val Acc: 0.8667
# Epoch 257 | Loss: 0.0978 | Val Acc: 0.8681
# Epoch 258 | Loss: 0.0968 | Val Acc: 0.8693
# Epoch 259 | Loss: 0.1001 | Val Acc: 0.8701
# Epoch 260 | Loss: 0.0986 | Val Acc: 0.8680
# Epoch 261 | Loss: 0.0953 | Val Acc: 0.8687
# Epoch 262 | Loss: 0.0994 | Val Acc: 0.8683
# Epoch 263 | Loss: 0.0962 | Val Acc: 0.8685
# Epoch 264 | Loss: 0.0941 | Val Acc: 0.8698
# Epoch 265 | Loss: 0.0961 | Val Acc: 0.8650
# Epoch 266 | Loss: 0.0979 | Val Acc: 0.8698
# Epoch 267 | Loss: 0.0965 | Val Acc: 0.8681
# Epoch 268 | Loss: 0.0969 | Val Acc: 0.8714
# Epoch 269 | Loss: 0.0964 | Val Acc: 0.8701
# Epoch 270 | Loss: 0.0925 | Val Acc: 0.8693
# Epoch 271 | Loss: 0.0941 | Val Acc: 0.8675
# Epoch 272 | Loss: 0.0958 | Val Acc: 0.8676
# Epoch 273 | Loss: 0.0965 | Val Acc: 0.8689
# Epoch 274 | Loss: 0.0944 | Val Acc: 0.8667
# Epoch 275 | Loss: 0.0937 | Val Acc: 0.8689
# Epoch 276 | Loss: 0.0947 | Val Acc: 0.8718
# Epoch 277 | Loss: 0.0912 | Val Acc: 0.8687
# Epoch 278 | Loss: 0.0933 | Val Acc: 0.8719
# Epoch 279 | Loss: 0.0932 | Val Acc: 0.8709
# Epoch 280 | Loss: 0.0973 | Val Acc: 0.8645
# Epoch 281 | Loss: 0.1000 | Val Acc: 0.8684
# Epoch 282 | Loss: 0.0960 | Val Acc: 0.8692
# Epoch 283 | Loss: 0.0957 | Val Acc: 0.8693
# Epoch 284 | Loss: 0.0939 | Val Acc: 0.8697
# Epoch 285 | Loss: 0.0969 | Val Acc: 0.8697
# Epoch 286 | Loss: 0.0947 | Val Acc: 0.8718
# Epoch 287 | Loss: 0.0959 | Val Acc: 0.8701
# Epoch 288 | Loss: 0.0959 | Val Acc: 0.8688
# Epoch 289 | Loss: 0.0920 | Val Acc: 0.8692
# Epoch 290 | Loss: 0.0910 | Val Acc: 0.8698
# Epoch 291 | Loss: 0.0972 | Val Acc: 0.8696
# Epoch 292 | Loss: 0.0924 | Val Acc: 0.8717
# Epoch 293 | Loss: 0.0923 | Val Acc: 0.8711
# Epoch 294 | Loss: 0.0943 | Val Acc: 0.8706
# Epoch 295 | Loss: 0.0911 | Val Acc: 0.8713
# Epoch 296 | Loss: 0.0941 | Val Acc: 0.8704
# Epoch 297 | Loss: 0.0952 | Val Acc: 0.8701
# Epoch 298 | Loss: 0.0930 | Val Acc: 0.8715
# Epoch 299 | Loss: 0.0938 | Val Acc: 0.8706
# Epoch 300 | Loss: 0.0901 | Val Acc: 0.8706
# 📊 Final Classification Report:
#               precision    recall  f1-score   support
#
#      Stage 0       0.82      0.70      0.76       642
#      Stage 1       0.82      0.77      0.79      1436
#      Stage 2       0.90      0.94      0.92      5115
#      Stage 3       0.76      0.69      0.72       459
#
#     accuracy                           0.87      7652
#    macro avg       0.82      0.78      0.80      7652
# weighted avg       0.87      0.87      0.87      7652
